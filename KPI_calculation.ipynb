# %% [markdown]
# # Imports

# %%
# Generic imports
import pickle
import numpy as np
import scipy.sparse as sparse
from collections import Counter
import json
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# PySpark imports
import pyspark.sql.functions as F
from pyspark.sql.types import ArrayType, StringType, BooleanType, IntegerType

# %% [markdown]
# # Paths to datasets

# %%
path2openAIRE = "/export/ml4ds/IntelComp/Datalake/openaire/20230328/parquet/"
path2S2 = "/export/ml4ds/IntelComp/Datalake/semanticscholar/20230418/parquet/"
path2PATSTAT = "/export/ml4ds/IntelComp/Datalake/patstat/2023_Spring/parquet/"
path2cordis = "/export/ml4ds/IntelComp/Datalake/CORDIS/20230823/parquet/"

# %% [markdown]
# # Variables and Functions for converting data to STI Viewer format

# %%
indicators = {
   "i01"   : "Count of scientific publications",
   "i02"   : "Average annual growth of scientific publications",
   "i03"   : "Topic distribution over time (share of a topic over time)",
   "i04"   : "Scientific publications specialisation",
   "i05"   : "Number of citable scientific publications",
   "i06"   : "Total number of citations of scientific publications",
   "i07"   : "Average number of citations per scientific publication",
   "i08"   : "Field weighted citation index of scientific publications",
   "i09"   : "Count of patents granted by the EPO by priority year",
   "i09a"  : "Number of private-public collaborations in patents. Perhaps using a collaboration index",
   "i09b"  : "distribution by year of topics in patents to the EPO (by priority year)",
   "i10"   : "Average annual growth of patents to the EPO in multi- year periods (3 years)",
   "i11"   : "Average backward citations: The average number of citations to other patents made by a patent",
   "i12"   : "Average forward citations: The number of citations received by the patent",
   "i12a"  : "Number of patents that are adopters, enablers, pioneers and mavericks",
   "i13"   : "Average citations to non-patent literature",
   "i13a"  : "Number of publications cited in patents",
   "i14"   : "patent specialisation in <secondary view>",
   "i15"   : "Count of publications in Emerging (multidisciplinary) Topics",
   "i16"   : "Top 25 emerging multidisciplinary fields globally per year (publication based-most citations)",
   "i17"   : "Emerging fields or topics in Patents",
   "i18"   : "Top 25 emerging multidisciplinary fields globally per year (patents based-most citations)",
   "i19"   : "Number of International co-publications",
   "i19a"  : "Collaboration Index ",
   "i20"   : "Number of cited international co-publications",
   "i20a"  : "FWCI vs Collaboration Index",
   "i21"   : "Share of international co-publications in total publications",
   "i22"   : "Share of cited international co-publications in total cited publications",
   "i23"   : "Number of Open Access publications",
   "i23b"  : "Number of publications published Open Access at a journal",
   "i23c"  : "Other indicators wrt to Open Science and FAIR principles",
   "i24"   : "Number of cited Open Access publications",
   "i24b"  : "Number of cited publications published in Open Access",
   "i24c"  : "FWCI for publications published in Open Access per secondary view",
   "i25"   : "Number of software linked to publications",
   "i25a"  : "Number of open source software linked to publications",
   "i25a1" : "Number of datasets linked to publications",
   "i25b"  : "Number of Open Access datasets linked to publications",
   "i26"   : "Share of cited Open Access publications in total Open Access publications",
   "i26b"  : "Share of cited Open Access publications in total Open Access publications at Journal",
   "i27"   : "Ranking of organisations according to the number of their multidisciplinary publications",
   "i27a"  : "Number of multidiscilinary publications",
   "i27b"  : "FWCI of multidiscilinary publications",
   "i28"   : "Ranking of organisations according to citations of multidiciplinary publications",
   "i29"   : "Network of organisations undertaking multidisciplinary research",
   "i30"   : "Common topics between industry and science and their evolution",
   "i30a"  : "Ranking and count of companies by secondary view ",
   "i30b"  : "* Technology topics supported by venture capital\n * Technology topics and associated applications by largest R&D investors\n * Technology topics from companies with highest company valuations",
   "i30c"  : "Venture Capital value per technology",
   "i31"   : "Ranking of companies (top 100) by number of publications by secondary view, and total number of publications",
   "i31a"  : "Average number of scientific publications per company in primary view by secondary view",
   "i31b"  : "Uptake score of companies (how close their R&D activity now is to the their scientific output",
   "i32"   : "Ranking of companies (top 100) by number of patents by secondary view, and total number of patents",
   "i32a"  : "Average number of patents per company in primary view by secondary view",
   "i32b"  : "Ranking of companies (top 100) by number of trademarks by secondary view, and total number of trademarks",
   "i32c"  : "Average number of trademarks per company in primary view by secondary view",
   "i33"   : "Share of companies applying for patents or publishing in scientific journals or conference proceedings or with participation in FP/ Nationally/Regionally funded projects",
   "i34"   : "Share of companies adapting to technological transformation trends (tech adopters)",
   "i35"   : "Share of companies investing in technological transformation (tech adopters)",
   "i36"   : "Share of companies raising funding for their technological transformation (tech generation)",
   "i37"   : "Share of companies with a sustainability strategy embedding technological transformation trends",
   "i38"   : "Names and counts of companies with environmental management certification (ISO 14001)/EMAS certified ",
   "i39"   : "None",
   "i40"   : "None",
   "i41"   : "* Total Budget\n * Average Budget\n * Number of companies (and % of total)",
   "i42"   : "Coverage of ESG Reports metrics for top 10 companies",
   "i42a"  : "Coverage of ESG Reports metrics for top 10 companies",
   "i42b"  : "Coverage of ESG Reports metrics for top 10 companies",
   "i42c"  : "Coverage of ESG Reports metrics for top 10 companies",
   "i42d"  : "Coverage of ESG Reports metrics for top 10 companies",
   "i42e"  : "Coverage of ESG Reports metrics for top 10 companies",
   "i43"   : "ESG performance for top 10 companies",
   "i44"   : "Regulations in Energy",
   "i45"   : "Green skills indicators"
}

# %%
secondary_view = {
    'as is'                   : 'sv00',
    'year'                    : 'sv01',
    'topic'                   : 'sv02',
    'category'                : 'sv03',
    'technology'              : 'sv04',
    'SDGs'                    : 'sv05',
    'organization'            : 'sv06',
    'NACE of companies'       : 'sv07',
    'sector of organization'  : 'sv08',
    'country'                 : 'sv09',
    'journal'                 : 'sv10',
    'publisher'               : 'sv11',
    'funder'                  : 'sv12',
    'IPC/CPC code'            : 'sv13',
    'topic-level06'           : 'sv14',
    'topic x year'            : 'sv15',
    'industry topics'         : 'sv16'
}

# %%
domain2id = {
    "Climate": "0",
    "AI": "1",
    "Cancer": "2"
}
geography2id = {
    "EU": "1",
    "ES": "6",
    "World" : "8",
    "EU (EC)" : "9",
    "FR" : "10"
}
pv2id = {
    "Climate": "01",
    "AI": "02",
    "Cancer": "03"
}

# %%
class JSONstruct:
    def __init__(self, domain, geography, pv, out_dir) -> None:
        self.domain = domain
        self.geography = geography
        self.dg = f"{self.domain} {self.geography}"
        self.dgid = f"dg{domain2id[self.domain]}{geography2id[self.geography]}"
        self.pv = pv
        self.pvId = f"pv{pv2id[self.pv]}"

        self.out_dir = Path(out_dir)
        self.out_dir.mkdir(parents=True, exist_ok=True)

    def set_info(self, keys, values, ind: str, sv: str, years=None):
        # Update common info
        self.ind = indicators[ind]
        self.indid = ind
        self.sv = sv
        self.svid = secondary_view[sv]

        if years:
            df = pd.DataFrame(data=values, columns=years, index=keys)
            # Create json
            self.info = [
                {
                    "domain": self.domain,
                    "country": self.geography,
                    "dg": self.dg,
                    "dgid": self.dgid,
                    "pv": self.pv,
                    "pvId": self.pvId,
                    "ind": self.ind,
                    "indid": self.indid,
                    "sv": self.sv,
                    "svid": self.svid,
                    "key": k,
                    "year": y,
                    "value": v,
                }
                for y, el in df.items()
                for k, v in el.items()
            ]
        else:
            df = pd.DataFrame(data=values, index=keys)
            # Create json
            self.info = [
                {
                    "domain": self.domain,
                    "country": self.geography,
                    "dg": self.dg,
                    "dgid": self.dgid,
                    "pv": self.pv,
                    "pvId": self.pvId,
                    "ind": self.ind,
                    "indid": self.indid,
                    "sv": self.sv,
                    "svid": self.svid,
                    "key": k,
                    "value": v,
                }
                for _, el in df.items()
                for k, v in el.items()
            ]

    def __repr__(self) -> str:
        if hasattr(self, "info"):
            return json.dumps(self.info)
        else:
            return json.dumps(
                {
                    "domain": self.domain,
                    "country": self.geography,
                    "dg": self.dg,
                    "dgid": self.dgid,
                    "pv": self.pv,
                    "pvId": self.pvId,
                }
            )

    def save(self):
        loc = self.out_dir.joinpath(
            f"{self.dgid}_{self.pvId}_{self.indid}_{self.svid}_data.json"
        )
        with loc.open("w") as fin:
            json.dump(self.info, fin, indent=4)

# %% [markdown]
# # KPI calculation

# %% [markdown]
# ## 1. Science indicators based on **OpenAIRE** and **PATSTAT**

# %% [markdown]
# ### 1.1. Load data for Analysis and Topic Model

# %% [markdown]
# #### 1.1.1. Artificial Intelligence in EU

# %% [markdown]
# ##### Prepare structure for exporting the results

# %%
# Prepare structure for exporting the results

domain = "AI"
geography = "EU"
pv = "AI"

years = [el for el in range(1990, 2023)]

indicators_dir = Path("/export/usuarios_ml4ds/jarenas/github/IntelComp/KPIs/WP3-pipelines/indicators/AI")
jstruct = JSONstruct(domain, geography, pv, indicators_dir)

# %% [markdown]
# ##### Load Topic Model variables

# %%
# Load topic model variables
path2model = "/export/usuarios_ml4ds/jarenas/github/IntelComp/ITMT/topicmodeler/WP6models/TMmodels/OA_Kwds3_AI_25tpc/"

with open(path2model + "corpus.txt") as fin:
    corpus_LDA = [el.split()[0].strip() for el in fin.readlines()]

thetas_LDA = sparse.load_npz(path2model + "TMmodel/thetas.npz")

with open(path2model + "TMmodel/tpc_labels.txt") as fin:
    topics_LDA = [el.strip() for el in fin.readlines()]

# %% [markdown]
# ##### Load relevant publications from the AI domain in the EU

# %%
# 1. Load all publications in the AI domain 
AI_OA_file = "file:///export/usuarios_ml4ds/jarenas/github/IntelComp/KPIs/WP3-pipelines/datasets/AI/OA_Kwds3_AI.parquet"
AI_OA_all = spark.read.parquet(AI_OA_file).select("id")

print('Number of publications with AI keywords:', AI_OA_all.count())
# Out:
# [Stage 3:>                                                          (0 + 1) / 1]
# Number of publications with AI keywords: 574346

# %%
# 2. Keep only those in countries belonging to EU
EU_countries = {
    'AT' : 'Austria',
    'BE' : 'Belgium',
    'BG' : 'Bulgaria',
    'CY' : 'Cyprus',
    'CZ' : 'Czech Republic',
    'DK' : 'Denmark',
    'EE' : 'Estonia',
    'FI' : 'Finland',
    'FR' : 'France',
    'DE' : 'Germany',
    'GR' : 'Greece',
    'HU' : 'Hungary',
    'IE' : 'Ireland',
    'IT' : 'Italy',
    'LV' : 'Latvia',
    'LT' : 'Lithuania',
    'LU' : 'Luxembourg',
    'MT' : 'Malta',
    'NL' : 'Netherlands',
    'PL' : 'Poland',
    'PT' : 'Portugal',
    'RO' : 'Romania',
    'SK' : 'Slovakia',
    'SI' : 'Slovenia',
    'ES' : 'Spain',
    'SE' : 'Sweden',
    'EU' : 'European Union'
}

EU_countries_list = [el for el in EU_countries.keys()]

# We create a dataframe with all organizations in the region of interest
organizations = spark.read.parquet(path2openAIRE + "organization").withColumnRenamed("id", "organization").cache()
print('Number of organization available:', organizations.count())

EU_organizations = organizations.filter(F.col("country").isin(EU_countries_list))
print('Number of EU organizations available:', EU_organizations.count())

# We load the dataframe that contains the affiliations of each result
result_affiliation = spark.read.parquet(path2openAIRE + "result_affiliation").cache()

# And keep only the entries that correspond to EU located organizations
EU_result_affiliation = result_affiliation.join(EU_organizations, on = "organization", how="inner")

# Finally, we use this to filter the papers that contain at least one affiliation in the region of interest
AI_OA_EU = AI_OA_all.join(EU_result_affiliation, on="id", how="inner").select(["id"]).dropDuplicates()
print('Number of publications with AI keywords and EU affiliation:', AI_OA_EU.count())
# Out:
# Number of organization available: 314059
# Number of EU organizations available: 85282
# [Stage 22:=====================================================>  (43 + 2) / 45]
# Number of publications with AI keywords and EU affiliation: 90540

# %%
# 3. Now, for each paper we will collect the list of all affiliation countries (EU and non EU)
all_result_affiliation = result_affiliation.join(organizations, on = "organization", how="inner")
AI_OA_EU = AI_OA_EU.join(all_result_affiliation, on = "id", how = "inner")
AI_OA_EU = AI_OA_EU.select(["id", "country"]).groupBy("id").agg(F.collect_list("country").alias("countries"))

# %%
# 4. Finally we need to filter publications according to year interval. We add the year to the available info

result_relevantdate = spark.read.parquet(path2openAIRE + "result_relevantdate").drop("type")

# Merge with relevant publications
AI_OA_EU = AI_OA_EU.join(result_relevantdate, on="id", how="inner")

# Extract year from subject (with format yyyy-mm-dd)
AI_OA_EU = AI_OA_EU.withColumn("year", F.substring(F.col("subject"), 1, 4).cast("integer")).drop("subject")

# Keep only publications in the desired range
AI_OA_EU = AI_OA_EU.filter(AI_OA_EU["year"].isNotNull() & (AI_OA_EU["year"] >= years[0]) & (AI_OA_EU["year"] <= years[-1]))

# We now sort in ascending order of year, to keep the most recent date after dropDuplicates
AI_OA_EU = AI_OA_EU.orderBy(AI_OA_EU["year"].asc()).dropDuplicates(["id"])

# %%
# We are done, we just need to rename the dataframe. We show the number of records and structure of the dataframe
OA_selected_publis = AI_OA_EU.cache()

print('Number of publications that will be used for the analysis:', OA_selected_publis.count())
OA_selected_publis.printSchema()
OA_selected_publis.show(n=10, truncate=120, vertical=True)
# Out:
# [Stage 47:=================================================>      (22 + 3) / 25]
# Number of publications that will be used for the analysis: 71325
# root
#  |-- id: string (nullable = true)
#  |-- countries: array (nullable = false)
#  |    |-- element: string (containsNull = false)
#  |-- year: integer (nullable = true)
#
# -RECORD 0---------------------------------------------------
#  id        | dedup_wf_001::09f350ef60910f36b59478d89d286a3f
#  countries | [FR, FR]
#  year      | 2020
# -RECORD 1---------------------------------------------------
#  id        | dedup_wf_001::258406a01703ac3775c2850b0cd08c94
#  countries | [US, FR, FR]
#  year      | 2016
# -RECORD 2---------------------------------------------------
#  id        | dedup_wf_001::34646d9d0a7cc2b44675869dfa066d36
#  countries | [ES]
#  year      | 2014
# -RECORD 3---------------------------------------------------
#  id        | dedup_wf_001::5bf156e1b20dc77dae84dd38d48b13ec
#  countries | [FR, FR]
#  year      | 2022
# -RECORD 4---------------------------------------------------
#  id        | dedup_wf_001::5d3f8e0b71eca29b089f5be13c9c3678
#  countries | [FR]
#  year      | 2020
# -RECORD 5---------------------------------------------------
#  id        | dedup_wf_001::5deef3cb3377834e8c9fb3e6977ef2b3
#  countries | [ES]
#  year      | 2009
# -RECORD 6---------------------------------------------------
#  id        | dedup_wf_001::6abb9f3ff8567d45896427075ed35cc5
#  countries | [BE]
#  year      | 2014
# -RECORD 7---------------------------------------------------
#  id        | dedup_wf_001::963bb7a6a37056343e9501cc98f5f361
#  countries | [FR, FR]
#  year      | 2015
# -RECORD 8---------------------------------------------------
#  id        | dedup_wf_001::abeef444f308a02bd6fd3ff2bbc6abbc
#  countries | [FR]
#  year      | 2007
# -RECORD 9---------------------------------------------------
#  id        | dedup_wf_001::ba994d89713dacc4c5c4f3897cc61083
#  countries | [FR, FR]
#  year      | 2011
# only showing top 10 rows

# %% [markdown]
# ##### Load patents in the AI EU, necessary for matching in indicator "Publications cited in patents by topic"

# %%
# We select only the patents from the AI domain
AI_patents = spark.read.parquet("file:///export/usuarios_ml4ds/jarenas/github/IntelComp/KPIs/WP3-pipelines/datasets/AI/PATSTAT_Kwds3_AI.parquet").select(["appln_id", "appln_auth"])

# We keep only the patents that have presented through the EPO office
AI_patents_EU = AI_patents.filter(F.col("appln_auth") == "EP")
AI_patents_EU = AI_patents_EU.select("appln_id")

# %%
# We are done, we just need to rename the dataframe. We show the number of records and structure of the dataframe
patstat_target_IND71 = AI_patents_EU.cache()

print('Number of patents for indicator 7.1.:', patstat_target_IND71.count())
patstat_target_IND71.printSchema()
patstat_target_IND71.show(n=10, truncate=120, vertical=True)
# Out:
# Number of patents for indicator 7.1.: 4608
# root
#  |-- appln_id: string (nullable = true)
#
# -RECORD 0-------------
#  appln_id | 191564
# -RECORD 1-------------
#  appln_id | 274101009
# -RECORD 2-------------
#  appln_id | 417260810
# -RECORD 3-------------
#  appln_id | 16700721
# -RECORD 4-------------
#  appln_id | 449493542
# -RECORD 5-------------
#  appln_id | 16709570
# -RECORD 6-------------
#  appln_id | 315729168
# -RECORD 7-------------
#  appln_id | 543215980
# -RECORD 8-------------
#  appln_id | 507652727
# -RECORD 9-------------
#  appln_id | 528428259
# only showing top 10 rows

# %% [markdown]
# #### 1.1.2. Artificial Intelligence in ES

# %% [markdown]
# ##### Prepare structure for exporting the results

# %%
# Prepare structure for exporting the results

domain = "AI"
geography = "ES"
pv = "AI"

years = [el for el in range(1990, 2023)]

indicators_dir = Path("/export/usuarios_ml4ds/jarenas/github/IntelComp/KPIs/WP3-pipelines/indicators/AI/ES")
jstruct = JSONstruct(domain, geography, pv, indicators_dir)

# %% [markdown]
# ##### Load Topic Model variables

# %%
# Load topic model variables
path2model = "/export/usuarios_ml4ds/jarenas/github/IntelComp/ITMT/topicmodeler/WP6models/TMmodels/OA_Kwds3_AI_25tpc/"

with open(path2model + "corpus.txt") as fin:
    corpus_LDA = [el.split()[0].strip() for el in fin.readlines()]

thetas_LDA = sparse.load_npz(path2model + "TMmodel/thetas.npz")

with open(path2model + "TMmodel/tpc_labels.txt") as fin:
    topics_LDA = [el.strip() for el in fin.readlines()]

# %% [markdown]
# ##### Load relevant publications from the AI domain in the EU

# %%
# 1. Load all publications in the AI domain 
AI_OA_file = "file:///export/usuarios_ml4ds/jarenas/github/IntelComp/KPIs/WP3-pipelines/datasets/AI/OA_Kwds3_AI.parquet"
AI_OA_all = spark.read.parquet(AI_OA_file).select("id")

print('Number of publications with AI keywords:', AI_OA_all.count())
# Out:
# [Stage 3:>                                                          (0 + 1) / 1]
# Number of publications with AI keywords: 574346

# %%
# 2. Keep only publications from ES

# We create a dataframe with all organizations in the region of interest
organizations = spark.read.parquet(path2openAIRE + "organization").withColumnRenamed("id", "organization").cache()
print('Number of organization available:', organizations.count())

ES_organizations = organizations.filter(F.col("country").isin(['ES']))
print('Number of ES organizations available:', ES_organizations.count())

# We load the dataframe that contains the affiliations of each result
result_affiliation = spark.read.parquet(path2openAIRE + "result_affiliation").cache()

# And keep only the entries that correspond to EU located organizations
ES_result_affiliation = result_affiliation.join(ES_organizations, on = "organization", how="inner")

# Finally, we use this to filter the papers that contain at least one affiliation in the region of interest
AI_OA_ES = AI_OA_all.join(ES_result_affiliation, on="id", how="inner").select(["id"]).dropDuplicates()
print('Number of publications with AI keywords and ES affiliation:', AI_OA_ES.count())
# Out:
# Number of organization available: 314059
# Number of ES organizations available: 8383
# [Stage 22:===================================================>    (41 + 4) / 45]
# Number of publications with AI keywords and ES affiliation: 12976

# %%
# 3. Now, for each paper we will collect the list of all affiliation countries (ES and non ES)
all_result_affiliation = result_affiliation.join(organizations, on = "organization", how="inner")
AI_OA_ES = AI_OA_ES.join(all_result_affiliation, on = "id", how = "inner")
AI_OA_ES = AI_OA_ES.select(["id", "country"]).groupBy("id").agg(F.collect_list("country").alias("countries"))

# %%
# 4. Finally we need to filter publications according to year interval. We add the year to the available info

result_relevantdate = spark.read.parquet(path2openAIRE + "result_relevantdate").drop("type")

# Merge with relevant publications
AI_OA_ES = AI_OA_ES.join(result_relevantdate, on="id", how="inner")

# Extract year from subject (with format yyyy-mm-dd)
AI_OA_ES = AI_OA_ES.withColumn("year", F.substring(F.col("subject"), 1, 4).cast("integer")).drop("subject")

# Keep only publications in the desired range
AI_OA_ES = AI_OA_ES.filter(AI_OA_ES["year"].isNotNull() & (AI_OA_ES["year"] >= years[0]) & (AI_OA_ES["year"] <= years[-1]))

# We now sort in ascending order of year, to keep the most recent date after dropDuplicates
AI_OA_ES = AI_OA_ES.orderBy(AI_OA_ES["year"].asc()).dropDuplicates(["id"])

# %%
# We are done, we just need to rename the dataframe. We show the number of records and structure of the dataframe
OA_selected_publis = AI_OA_ES.cache()

print('Number of publications that will be used for the analysis:', OA_selected_publis.count())
OA_selected_publis.printSchema()
OA_selected_publis.show(n=10, truncate=120, vertical=True)
# Out:
# [Stage 49:=====================================================>(197 + 3) / 200]
# Number of publications that will be used for the analysis: 9162
# root
#  |-- id: string (nullable = true)
#  |-- countries: array (nullable = false)
#  |    |-- element: string (containsNull = false)
#  |-- year: integer (nullable = true)
#
# -RECORD 0---------------------------------------------------
#  id        | dedup_wf_001::34646d9d0a7cc2b44675869dfa066d36
#  countries | [ES]
#  year      | 2014
# -RECORD 1---------------------------------------------------
#  id        | dedup_wf_001::5deef3cb3377834e8c9fb3e6977ef2b3
#  countries | [ES]
#  year      | 2009
# -RECORD 2---------------------------------------------------
#  id        | doi_________::0c0d01df0204a9a7708db05125c85bc8
#  countries | [ES]
#  year      | 2020
# -RECORD 3---------------------------------------------------
#  id        | doi_________::179940379b791d017263d66742bb9682
#  countries | [ES]
#  year      | 2020
# -RECORD 4---------------------------------------------------
#  id        | doi_________::2718557349ebc1f018a8b6985abf6a4d
#  countries | [ES]
#  year      | 2020
# -RECORD 5---------------------------------------------------
#  id        | doi_________::34f660b354cc8d16117f46bdfdb3924b
#  countries | [ES, ES]
#  year      | 2010
# -RECORD 6---------------------------------------------------
#  id        | doi_________::3a135c2238edeb11df53f95f1e9e6aed
#  countries | [ES]
#  year      | 2004
# -RECORD 7---------------------------------------------------
#  id        | doi_________::44d0db7b3b78b7269aed8cb475df6dc6
#  countries | [ES]
#  year      | 2018
# -RECORD 8---------------------------------------------------
#  id        | doi_________::52464dd243441416facc48c37b5f821a
#  countries | [ES, IN]
#  year      | 2018
# -RECORD 9---------------------------------------------------
#  id        | doi_________::62d687d7cc2f0370d7db581f6c4c6597
#  countries | [ES]
#  year      | 2005
# only showing top 10 rows

# %% [markdown]
# ##### Load patents in the AI EU, necessary for matching in indicator "Publications cited in patents by topic"

# %%
# We select only the patents from the AI domain
AI_patents = spark.read.parquet("file:///export/usuarios_ml4ds/jarenas/github/IntelComp/KPIs/WP3-pipelines/datasets/AI/PATSTAT_Kwds3_AI.parquet").select(["appln_id", "appln_auth"])

# We keep only the patents that have presented through the EPO office
AI_patents_EU = AI_patents.filter(F.col("appln_auth") == "EP")
AI_patents_EU = AI_patents_EU.select("appln_id")

# %%
# We are done, we just need to rename the dataframe. We show the number of records and structure of the dataframe
patstat_target_IND71 = AI_patents_EU.cache()

print('Number of patents for indicator 7.1.:', patstat_target_IND71.count())
patstat_target_IND71.printSchema()
patstat_target_IND71.show(n=10, truncate=120, vertical=True)
# Out:
# Number of patents for indicator 7.1.: 4608
# root
#  |-- appln_id: string (nullable = true)
#
# -RECORD 0-------------
#  appln_id | 191564
# -RECORD 1-------------
#  appln_id | 274101009
# -RECORD 2-------------
#  appln_id | 417260810
# -RECORD 3-------------
#  appln_id | 16700721
# -RECORD 4-------------
#  appln_id | 449493542
# -RECORD 5-------------
#  appln_id | 16709570
# -RECORD 6-------------
#  appln_id | 315729168
# -RECORD 7-------------
#  appln_id | 543215980
# -RECORD 8-------------
#  appln_id | 507652727
# -RECORD 9-------------
#  appln_id | 528428259
# only showing top 10 rows

# %% [markdown]
# #### 1.1.3. Cancer in EU

# %% [markdown]
# ##### Prepare structure for exporting the results

# %%
# Prepare structure for exporting the results

domain = "Cancer"
geography = "EU"
pv = "Cancer"

years = [el for el in range(2000, 2021)]

indicators_dir = Path("/export/usuarios_ml4ds/jarenas/github/IntelComp/KPIs/WP3-pipelines/indicators/Cancer/EU/Science")
jstruct = JSONstruct(domain, geography, pv, indicators_dir)

# %% [markdown]
# ##### Load Topic Model variables

# %%
# Load topic model variables
path2model = "/export/usuarios_ml4ds/jarenas/github/IntelComp/ITMT/topicmodeler/WP6models/TMmodels/OA_cancer_25tpc/"

with open(path2model + "corpus.txt") as fin:
    corpus_LDA = [el.split()[0].strip() for el in fin.readlines()]

thetas_LDA = sparse.load_npz(path2model + "TMmodel/thetas.npz")

with open(path2model + "TMmodel/tpc_labels.txt") as fin:
    topics_LDA = [el.strip() for el in fin.readlines()]

# %% [markdown]
# ##### Load relevant publications from the cancer domain in the EU

# %%
# 1. Load all publications in the AI domain 
cancer_OA_file = "file:///export/usuarios_ml4ds/jarenas/github/IntelComp/KPIs/WP3-pipelines/datasets/cancer/OA_Cancer.parquet"
cancer_OA_all = spark.read.parquet(cancer_OA_file).select("id")

print('Number of publications in the cancer domain:', cancer_OA_all.count())
# Out:
# Number of publications in the cancer domain: 2393228

# %%
# 2. Keep only those in countries belonging to EU
EU_countries = {
    'AT' : 'Austria',
    'BE' : 'Belgium',
    'BG' : 'Bulgaria',
    'CY' : 'Cyprus',
    'CZ' : 'Czech Republic',
    'DK' : 'Denmark',
    'EE' : 'Estonia',
    'FI' : 'Finland',
    'FR' : 'France',
    'DE' : 'Germany',
    'GR' : 'Greece',
    'HU' : 'Hungary',
    'IE' : 'Ireland',
    'IT' : 'Italy',
    'LV' : 'Latvia',
    'LT' : 'Lithuania',
    'LU' : 'Luxembourg',
    'MT' : 'Malta',
    'NL' : 'Netherlands',
    'PL' : 'Poland',
    'PT' : 'Portugal',
    'RO' : 'Romania',
    'SK' : 'Slovakia',
    'SI' : 'Slovenia',
    'ES' : 'Spain',
    'SE' : 'Sweden',
    'EU' : 'European Union'
}

EU_countries_list = [el for el in EU_countries.keys()]

# We create a dataframe with all organizations in the region of interest
organizations = spark.read.parquet(path2openAIRE + "organization").withColumnRenamed("id", "organization").cache()
print('Number of organization available:', organizations.count())

EU_organizations = organizations.filter(F.col("country").isin(EU_countries_list))
print('Number of EU organizations available:', EU_organizations.count())

# We load the dataframe that contains the affiliations of each result
result_affiliation = spark.read.parquet(path2openAIRE + "result_affiliation").cache()

# And keep only the entries that correspond to EU located organizations
EU_result_affiliation = result_affiliation.join(EU_organizations, on = "organization", how="inner")

# Finally, we use this to filter the papers that contain at least one affiliation in the region of interest
cancer_OA_EU = cancer_OA_all.join(EU_result_affiliation, on="id", how="inner").select(["id"]).dropDuplicates()
print('Number of cancer publications in dataset with EU affiliation:', cancer_OA_EU.count())
# Out:
# Number of organization available: 314059
# Number of EU organizations available: 85282
# [Stage 26:===================================================>    (41 + 4) / 45]
# Number of cancer publications in dataset with EU affiliation: 467549

# %%
# 3. Now, for each paper we will collect the list of all affiliation countries (EU and non EU)
all_result_affiliation = result_affiliation.join(organizations, on = "organization", how="inner")
cancer_OA_EU = cancer_OA_EU.join(all_result_affiliation, on = "id", how = "inner")
cancer_OA_EU = cancer_OA_EU.select(["id", "country"]).groupBy("id").agg(F.collect_list("country").alias("countries"))

# %%
# 4. Finally we need to filter publications according to year interval. We add the year to the available info

result_relevantdate = spark.read.parquet(path2openAIRE + "result_relevantdate").drop("type")

# Merge with relevant publications
cancer_OA_EU = cancer_OA_EU.join(result_relevantdate, on="id", how="inner")

# Extract year from subject (with format yyyy-mm-dd)
cancer_OA_EU = cancer_OA_EU.withColumn("year", F.substring(F.col("subject"), 1, 4).cast("integer")).drop("subject")

# Keep only publications in the desired range
cancer_OA_EU = cancer_OA_EU.filter(cancer_OA_EU["year"].isNotNull() & (cancer_OA_EU["year"] >= years[0]) & (cancer_OA_EU["year"] <= years[-1]))

# We now sort in ascending order of year, to keep the most recent date after dropDuplicates
cancer_OA_EU = cancer_OA_EU.orderBy(cancer_OA_EU["year"].asc()).dropDuplicates(["id"])

# %%
# We are done, we just need to rename the dataframe. We show the number of records and structure of the dataframe
OA_selected_publis = cancer_OA_EU.cache()

print('Number of publications that will be used for the analysis:', OA_selected_publis.count())
OA_selected_publis.printSchema()
OA_selected_publis.show(n=10, truncate=120, vertical=True)
# Out:
# [Stage 52:=================================================>   (187 + 13) / 200]
# Number of publications that will be used for the analysis: 452345
# root
#  |-- id: string (nullable = true)
#  |-- countries: array (nullable = false)
#  |    |-- element: string (containsNull = false)
#  |-- year: integer (nullable = true)
#
# -RECORD 0---------------------------------------------------
#  id        | doi_dedup___::000e600156867c15e1ab7adbabd38b3f
#  countries | [FR, FR, FR, FR, FR, FR, FR, FR, FR, FR]
#  year      | 2018
# -RECORD 1---------------------------------------------------
#  id        | doi_dedup___::001462739f896c2517149b443fdb4e9e
#  countries | [IT]
#  year      | 2007
# -RECORD 2---------------------------------------------------
#  id        | doi_dedup___::005d80bc3a5764bfa717a2bbafb8543d
#  countries | [CH, CZ]
#  year      | 2017
# -RECORD 3---------------------------------------------------
#  id        | doi_dedup___::00958a691603ffc26b7b982ab0b9b966
#  countries | [NL]
#  year      | 2008
# -RECORD 4---------------------------------------------------
#  id        | doi_dedup___::00bd12b6a2eb48e1ef989518c5e774a9
#  countries | [IT]
#  year      | 2011
# -RECORD 5---------------------------------------------------
#  id        | doi_dedup___::0123b86748c2c49c99dbe25d573a3eaf
#  countries | [FR]
#  year      | 2010
# -RECORD 6---------------------------------------------------
#  id        | doi_dedup___::013f6daf55aae551c7c038103b3b365b
#  countries | [US, GB, US, IT]
#  year      | 2014
# -RECORD 7---------------------------------------------------
#  id        | doi_dedup___::014a749239a01a344ad8ab624f728c77
#  countries | [DE]
#  year      | 2014
# -RECORD 8---------------------------------------------------
#  id        | doi_dedup___::016bc01a6c1a0c19228ea0da2b6166d8
#  countries | [BE, FR]
#  year      | 2001
# -RECORD 9---------------------------------------------------
#  id        | doi_dedup___::0170114091dcd2c1966d6598e8336957
#  countries | [AT]
#  year      | 2005
# only showing top 10 rows

# %% [markdown]
# ##### Load patents in cancer in EU, necessary for matching in indicator "Publications cited in patents by topic"

# %%
# We select only the patents from the cancer domain
cancer_patents = spark.read.parquet("file:///export/usuarios_ml4ds/jarenas/github/IntelComp/KPIs/WP3-pipelines/datasets/cancer/PATSTAT_DC_Cancer.parquet").select(["appln_id", "appln_auth"])

# We keep only the patents that have presented through the EPO office
cancer_patents_EU = cancer_patents.filter(F.col("appln_auth") == "EP")
cancer_patents_EU = cancer_patents_EU.select("appln_id")

# %%
# We are done, we just need to rename the dataframe. We show the number of records and structure of the dataframe
patstat_target_IND71 = cancer_patents_EU.cache()

print('Number of patents for indicator 7.1.:', patstat_target_IND71.count())
patstat_target_IND71.printSchema()
patstat_target_IND71.show(n=10, truncate=120, vertical=True)
# Out:
# Number of patents for indicator 7.1.: 30509
# root
#  |-- appln_id: string (nullable = true)
#
# -RECORD 0-------------
#  appln_id | 414821201
# -RECORD 1-------------
#  appln_id | 524948270
# -RECORD 2-------------
#  appln_id | 528123678
# -RECORD 3-------------
#  appln_id | 333335694
# -RECORD 4-------------
#  appln_id | 56402702
# -RECORD 5-------------
#  appln_id | 538242950
# -RECORD 6-------------
#  appln_id | 201056
# -RECORD 7-------------
#  appln_id | 575382014
# -RECORD 8-------------
#  appln_id | 184924
# -RECORD 9-------------
#  appln_id | 438322183
# only showing top 10 rows

# %% [markdown]
# #### 1.1.4. Cancer in the world

# %% [markdown]
# ##### Prepare structure for exporting the results

# %%
# Prepare structure for exporting the results

domain = "Cancer"
geography = "World"
pv = "Cancer"

years = [el for el in range(2000, 2021)]

indicators_dir = Path("/export/usuarios_ml4ds/jarenas/github/IntelComp/KPIs/WP3-pipelines/indicators/Cancer/World/Science")
jstruct = JSONstruct(domain, geography, pv, indicators_dir)

# %% [markdown]
# ##### Load Topic Model variables

# %%
# Load topic model variables
path2model = "/export/usuarios_ml4ds/jarenas/github/IntelComp/ITMT/topicmodeler/WP6models/TMmodels/OA_cancer_25tpc/"

with open(path2model + "corpus.txt") as fin:
    corpus_LDA = [el.split()[0].strip() for el in fin.readlines()]

thetas_LDA = sparse.load_npz(path2model + "TMmodel/thetas.npz")

with open(path2model + "TMmodel/tpc_labels.txt") as fin:
    topics_LDA = [el.strip() for el in fin.readlines()]

# %% [markdown]
# ##### Load relevant publications from the cancer domain in the World

# %%
# 1. Load all publications in the AI domain 
cancer_OA_file = "file:///export/usuarios_ml4ds/jarenas/github/IntelComp/KPIs/WP3-pipelines/datasets/cancer/OA_Cancer.parquet"
cancer_OA_all = spark.read.parquet(cancer_OA_file).select("id")

print('Number of publications in the cancer domain:', cancer_OA_all.count())
# Out:
# [Stage 1196:================================================>     (36 + 4) / 40]
# Number of publications in the cancer domain: 2393228

# %%
# 2. Now, for each paper we will collect the list of all affiliation countries

# We create a dataframe with all organizations
organizations = spark.read.parquet(path2openAIRE + "organization").withColumnRenamed("id", "organization").cache()
print('Number of organization available:', organizations.count())

# We load the dataframe that contains the affiliations of each result
result_affiliation = spark.read.parquet(path2openAIRE + "result_affiliation").cache()
all_result_affiliation = result_affiliation.join(organizations, on = "organization", how="inner")

cancer_OA_all = cancer_OA_all.join(all_result_affiliation, on = "id", how = "inner")
cancer_OA_all = cancer_OA_all.select(["id", "country"]).groupBy("id").agg(F.collect_list("country").alias("countries"))
# Out:
# 23/10/09 21:00:45 WARN CacheManager: Asked to cache already cached data.
# Number of organization available: 314059
# 23/10/09 21:00:46 WARN CacheManager: Asked to cache already cached data.

# %%
# 3. Finally we need to filter publications according to year interval. We add the year to the available info

result_relevantdate = spark.read.parquet(path2openAIRE + "result_relevantdate").drop("type")

# Merge with relevant publications
cancer_OA_all = cancer_OA_all.join(result_relevantdate, on="id", how="inner")

# Extract year from subject (with format yyyy-mm-dd)
cancer_OA_all = cancer_OA_all.withColumn("year", F.substring(F.col("subject"), 1, 4).cast("integer")).drop("subject")

# Keep only publications in the desired range
cancer_OA_all = cancer_OA_all.filter(cancer_OA_all["year"].isNotNull() & (cancer_OA_all["year"] >= years[0]) & (cancer_OA_all["year"] <= years[-1]))

# We now sort in ascending order of year, to keep the most recent date after dropDuplicates
cancer_OA_all = cancer_OA_all.orderBy(cancer_OA_all["year"].asc()).dropDuplicates(["id"])

# %%
# We are done, we just need to rename the dataframe. We show the number of records and structure of the dataframe
OA_selected_publis = cancer_OA_all.cache()

print('Number of publications that will be used for the analysis:', OA_selected_publis.count())
OA_selected_publis.printSchema()
OA_selected_publis.show(n=10, truncate=120, vertical=True)
# Out:
# [Stage 1218:==================================================> (194 + 6) / 200]
# Number of publications that will be used for the analysis: 1687467
# root
#  |-- id: string (nullable = true)
#  |-- countries: array (nullable = false)
#  |    |-- element: string (containsNull = false)
#  |-- year: integer (nullable = true)
#
# -RECORD 0------------------------------------------------------
#  id        | doi_dedup___::000e32b41396c454e9d665a32c959feb
#  countries | [US, US]
#  year      | 2010
# -RECORD 1------------------------------------------------------
#  id        | doi_dedup___::000e600156867c15e1ab7adbabd38b3f
#  countries | [FR, FR, FR, FR, FR, FR, FR, FR, FR, FR]
#  year      | 2018
# -RECORD 2------------------------------------------------------
#  id        | doi_dedup___::00125cc96eec56113d30e50b5be1a934
#  countries | [US]
#  year      | 2010
# -RECORD 3------------------------------------------------------
#  id        | doi_dedup___::0012b7892e6b5642990035b30882bd4a
#  countries | [GB, GB]
#  year      | 2002
# -RECORD 4------------------------------------------------------
#  id        | doi_dedup___::0012c4d8650abbb6210aef4538dcbdad
#  countries | [US, US, NZ, US, US, US, US, UNKNOWN, US, US, US]
#  year      | 2012
# -RECORD 5------------------------------------------------------
#  id        | doi_dedup___::001462739f896c2517149b443fdb4e9e
#  countries | [IT]
#  year      | 2007
# -RECORD 6------------------------------------------------------
#  id        | doi_dedup___::001ddbaf95493141890fd7a4ee97c700
#  countries | [CH]
#  year      | 2000
# -RECORD 7------------------------------------------------------
#  id        | doi_dedup___::002a7805e8750fb6089e4bc3486949fd
#  countries | [US]
#  year      | 2007
# -RECORD 8------------------------------------------------------
#  id        | doi_dedup___::002c7ba6773f1ad48b0c29e356b41675
#  countries | [US, US, US]
#  year      | 2005
# -RECORD 9------------------------------------------------------
#  id        | doi_dedup___::003196d621a2b5db7cb74b6821cef719
#  countries | [GB]
#  year      | 2017
# only showing top 10 rows

# %% [markdown]
# ##### Load patents in cancer, necessary for matching in indicator "Publications cited in patents by topic"

# %%
# We select only the patents from the cancer domain
cancer_patents = spark.read.parquet("file:///export/usuarios_ml4ds/jarenas/github/IntelComp/KPIs/WP3-pipelines/datasets/cancer/PATSTAT_DC_Cancer.parquet").select(["appln_id", "appln_auth"])

# In this case, we keep all patents, not just those presented through the EPO office
# We keep only the patents that have presented through the EPO office
# cancer_patents_EU = cancer_patents.filter(F.col("appln_auth") == "EP")
# cancer_patents_EU = cancer_patents_EU.select("appln_id")

# %%
# We are done, we just need to rename the dataframe. We show the number of records and structure of the dataframe
patstat_target_IND71 = cancer_patents.cache()

print('Number of patents for indicator 7.1.:', patstat_target_IND71.count())
patstat_target_IND71.printSchema()
patstat_target_IND71.show(n=10, truncate=120, vertical=True)
# Out:
# Number of patents for indicator 7.1.: 213405
# root
#  |-- appln_id: string (nullable = true)
#  |-- appln_auth: string (nullable = true)
#
# -RECORD 0---------------
#  appln_id   | 414821201
#  appln_auth | EP
# -RECORD 1---------------
#  appln_id   | 407083279
#  appln_auth | CN
# -RECORD 2---------------
#  appln_id   | 524948270
#  appln_auth | EP
# -RECORD 3---------------
#  appln_id   | 528123678
#  appln_auth | EP
# -RECORD 4---------------
#  appln_id   | 333335694
#  appln_auth | EP
# -RECORD 5---------------
#  appln_id   | 499367708
#  appln_auth | WO
# -RECORD 6---------------
#  appln_id   | 56402702
#  appln_auth | EP
# -RECORD 7---------------
#  appln_id   | 426347779
#  appln_auth | US
# -RECORD 8---------------
#  appln_id   | 538242950
#  appln_auth | EP
# -RECORD 9---------------
#  appln_id   | 536579516
#  appln_auth | KR
# only showing top 10 rows

# %% [markdown]
# #### 1.1.5. Cancer publications funded by the EC

# %% [markdown]
# ##### Prepare structure for exporting the results

# %%
# Prepare structure for exporting the results

domain = "Cancer"
geography = "EU (EC)"
pv = "Cancer"

years = [el for el in range(2000, 2021)]

indicators_dir = Path("/export/usuarios_ml4ds/jarenas/github/IntelComp/KPIs/WP3-pipelines/indicators/Cancer/EU_EC/Science")
jstruct = JSONstruct(domain, geography, pv, indicators_dir)

# %% [markdown]
# ##### Load Topic Model variables

# %%
# Load topic model variables
path2model = "/export/usuarios_ml4ds/jarenas/github/IntelComp/ITMT/topicmodeler/WP6models/TMmodels/OA_cancer_25tpc/"

with open(path2model + "corpus.txt") as fin:
    corpus_LDA = [el.split()[0].strip() for el in fin.readlines()]

thetas_LDA = sparse.load_npz(path2model + "TMmodel/thetas.npz")

with open(path2model + "TMmodel/tpc_labels.txt") as fin:
    topics_LDA = [el.strip() for el in fin.readlines()]

# %% [markdown]
# ##### Load relevant publications from the cancer domain funded by the European Commission

# %%
# 1. Load all publications in the AI domain 
cancer_OA_file = "file:///export/usuarios_ml4ds/jarenas/github/IntelComp/KPIs/WP3-pipelines/datasets/cancer/OA_Cancer.parquet"
cancer_OA_all = spark.read.parquet(cancer_OA_file).select("id")

print('Number of publications in the cancer domain:', cancer_OA_all.count())
# Out:
# Number of publications in the cancer domain: 2393228

# %%
# 2. Now, we select only the publications funded by the EC

# Load table of acknowledgements, and keep only the ones that are relevant for the cancer-related papers
result_project = spark.read.parquet(path2openAIRE + "result_project")
result_project = result_project.join(cancer_OA_all, on="id", how="inner").select(["id", "project"]).cache()
print('Number of acknowledgments available:', result_project.count())

# Load table of projects and fill in the information regarding the funders of each project
project_funding = spark.read.parquet(path2openAIRE + "project_funding").withColumnRenamed("id","project").cache()
result_funder = result_project.join(project_funding, on="project", how="inner")

# Keep only entries corresponding to acks to the EC
result_funder = result_funder.filter(F.col("funder") == "European Commission")

# Finally, we use this to filter the papers that contain acknowledgment to the European Commission funding
cancer_OA_EC = cancer_OA_all.join(result_funder, on="id", how="inner").select(["id"]).dropDuplicates()
print('Number of cancer publications in dataset with ACK to the EC:', cancer_OA_EC.count())
# Out:
# 23/10/09 21:39:13 WARN CacheManager: Asked to cache already cached data.
# Number of acknowledgments available: 234889
# 23/10/09 21:39:14 WARN CacheManager: Asked to cache already cached data.
# [Stage 2214:==================================================>   (45 + 3) / 48]
# Number of cancer publications in dataset with ACK to the EC: 18175

# %%
# 3. Now, for each paper we will collect the list of all affiliation countries

# We create a dataframe with all organizations
organizations = spark.read.parquet(path2openAIRE + "organization").withColumnRenamed("id", "organization").cache()
print('Number of organization available:', organizations.count())

# We load the dataframe that contains the affiliations of each result
result_affiliation = spark.read.parquet(path2openAIRE + "result_affiliation").cache()
all_result_affiliation = result_affiliation.join(organizations, on = "organization", how="inner")

cancer_OA_EC = cancer_OA_EC.join(all_result_affiliation, on = "id", how = "inner")
cancer_OA_EC = cancer_OA_EC.select(["id", "country"]).groupBy("id").agg(F.collect_list("country").alias("countries"))
# Out:
# 23/10/09 21:39:58 WARN CacheManager: Asked to cache already cached data.
# Number of organization available: 314059
# 23/10/09 21:39:58 WARN CacheManager: Asked to cache already cached data.

# %%
# 4. Finally we need to filter publications according to year interval. We add the year to the available info

result_relevantdate = spark.read.parquet(path2openAIRE + "result_relevantdate").drop("type")

# Merge with relevant publications
cancer_OA_EC = cancer_OA_EC.join(result_relevantdate, on="id", how="inner")

# Extract year from subject (with format yyyy-mm-dd)
cancer_OA_EC = cancer_OA_EC.withColumn("year", F.substring(F.col("subject"), 1, 4).cast("integer")).drop("subject")

# Keep only publications in the desired range
cancer_OA_EC = cancer_OA_EC.filter(cancer_OA_EC["year"].isNotNull() & (cancer_OA_EC["year"] >= years[0]) & (cancer_OA_EC["year"] <= years[-1]))

# We now sort in ascending order of year, to keep the most recent date after dropDuplicates
cancer_OA_EC = cancer_OA_EC.orderBy(cancer_OA_EC["year"].asc()).dropDuplicates(["id"])

# %%
# We are done, we just need to rename the dataframe. We show the number of records and structure of the dataframe
OA_selected_publis = cancer_OA_EC.cache()

print('Number of publications that will be used for the analysis:', OA_selected_publis.count())
OA_selected_publis.printSchema()
OA_selected_publis.show(n=10, truncate=120, vertical=True)
# Out:
# [Stage 2245:===================================================>(198 + 2) / 200]]]]
# Number of publications that will be used for the analysis: 16648
# root
#  |-- id: string (nullable = true)
#  |-- countries: array (nullable = false)
#  |    |-- element: string (containsNull = false)
#  |-- year: integer (nullable = true)
#
# -RECORD 0---------------------------------------------------
#  id        | doi_dedup___::03c75a744cab7deb47ad63cd2bf049ce
#  countries | [DE, GB, GB, DE]
#  year      | 2018
# -RECORD 1---------------------------------------------------
#  id        | doi_dedup___::04c7f18326077ded5f5bac517569c5a2
#  countries | [DE, NL]
#  year      | 2014
# -RECORD 2---------------------------------------------------
#  id        | doi_dedup___::0669f38a2d4c5303e0ce14b4524aaff1
#  countries | [CH]
#  year      | 2018
# -RECORD 3---------------------------------------------------
#  id        | doi_dedup___::0b08a28e3434313c36c195fe6e92f623
#  countries | [DE, DE]
#  year      | 2017
# -RECORD 4---------------------------------------------------
#  id        | doi_dedup___::0c03a0efdc185f0840f9987b46e6a2a3
#  countries | [NL, NL]
#  year      | 2014
# -RECORD 5---------------------------------------------------
#  id        | doi_dedup___::11d2062e4714eac52081850e5c3ec8fb
#  countries | [DE, DE, DE, US, RU, DE, CN, DE]
#  year      | 2020
# -RECORD 6---------------------------------------------------
#  id        | doi_dedup___::14e4e77826e0b55cfc33b20a79823c2f
#  countries | [DE, DE, DE]
#  year      | 2013
# -RECORD 7---------------------------------------------------
#  id        | doi_dedup___::19f47681f6b747accb3666d815394ac1
#  countries | [US, US, US]
#  year      | 2013
# -RECORD 8---------------------------------------------------
#  id        | doi_dedup___::1b21da19e3d201edfdfc57daf0b5b30c
#  countries | [IT]
#  year      | 2010
# -RECORD 9---------------------------------------------------
#  id        | doi_dedup___::1e4ba11aebea71f326894c5439158519
#  countries | [US, NL, NL, US, US, US, US, US, US, US, US]
#  year      | 2013
# only showing top 10 rows

# %% [markdown]
# ##### Load patents in cancer, necessary for matching in indicator "Publications cited in patents by topic"

# %%
# We select only the patents from the cancer domain
cancer_patents = spark.read.parquet("file:///export/usuarios_ml4ds/jarenas/github/IntelComp/KPIs/WP3-pipelines/datasets/cancer/PATSTAT_DC_Cancer.parquet").select(["appln_id", "appln_auth"])

# In this case, we keep all patents, not just those presented through the EPO office
# We keep only the patents that have presented through the EPO office
# cancer_patents_EU = cancer_patents.filter(F.col("appln_auth") == "EP")
# cancer_patents_EU = cancer_patents_EU.select("appln_id")

# %%
# We are done, we just need to rename the dataframe. We show the number of records and structure of the dataframe
patstat_target_IND71 = cancer_patents.cache()

print('Number of patents for indicator 7.1.:', patstat_target_IND71.count())
patstat_target_IND71.printSchema()
patstat_target_IND71.show(n=10, truncate=120, vertical=True)
# Out:
# 23/10/09 21:42:40 WARN CacheManager: Asked to cache already cached data.
# Number of patents for indicator 7.1.: 213405
# root
#  |-- appln_id: string (nullable = true)
#  |-- appln_auth: string (nullable = true)
#
# -RECORD 0---------------
#  appln_id   | 414821201
#  appln_auth | EP
# -RECORD 1---------------
#  appln_id   | 407083279
#  appln_auth | CN
# -RECORD 2---------------
#  appln_id   | 524948270
#  appln_auth | EP
# -RECORD 3---------------
#  appln_id   | 528123678
#  appln_auth | EP
# -RECORD 4---------------
#  appln_id   | 333335694
#  appln_auth | EP
# -RECORD 5---------------
#  appln_id   | 499367708
#  appln_auth | WO
# -RECORD 6---------------
#  appln_id   | 56402702
#  appln_auth | EP
# -RECORD 7---------------
#  appln_id   | 426347779
#  appln_auth | US
# -RECORD 8---------------
#  appln_id   | 538242950
#  appln_auth | EP
# -RECORD 9---------------
#  appln_id   | 536579516
#  appln_auth | KR
# only showing top 10 rows

# %% [markdown]
# #### 1.1.6. Cancer in FR

# %% [markdown]
# ##### Prepare structure for exporting the results

# %%
# Prepare structure for exporting the results

domain = "Cancer"
geography = "FR"
pv = "Cancer"

years = [el for el in range(2000, 2021)]

indicators_dir = Path("/export/usuarios_ml4ds/jarenas/github/IntelComp/KPIs/WP3-pipelines/indicators/Cancer/FR/Science")
jstruct = JSONstruct(domain, geography, pv, indicators_dir)

# %% [markdown]
# ##### Load Topic Model variables

# %%
# Load topic model variables
path2model = "/export/usuarios_ml4ds/jarenas/github/IntelComp/ITMT/topicmodeler/WP6models/TMmodels/OA_cancer_25tpc/"

with open(path2model + "corpus.txt") as fin:
    corpus_LDA = [el.split()[0].strip() for el in fin.readlines()]

thetas_LDA = sparse.load_npz(path2model + "TMmodel/thetas.npz")

with open(path2model + "TMmodel/tpc_labels.txt") as fin:
    topics_LDA = [el.strip() for el in fin.readlines()]

# %% [markdown]
# ##### Load relevant publications from the cancer domain with FR affiliation

# %%
# 1. Load all publications in the AI domain 
cancer_OA_file = "file:///export/usuarios_ml4ds/jarenas/github/IntelComp/KPIs/WP3-pipelines/datasets/cancer/OA_Cancer.parquet"
cancer_OA_all = spark.read.parquet(cancer_OA_file).select("id")

print('Number of publications in the cancer domain:', cancer_OA_all.count())
# Out:
# [Stage 1:===================================================>     (36 + 4) / 40]
# Number of publications in the cancer domain: 2393228

# %%
# 2. Keep only publications from FR

# We create a dataframe with all organizations in the region of interest
organizations = spark.read.parquet(path2openAIRE + "organization").withColumnRenamed("id", "organization").cache()
print('Number of organization available:', organizations.count())

FR_organizations = organizations.filter(F.col("country").isin(['FR']))
print('Number of FR organizations available:', FR_organizations.count())

# We load the dataframe that contains the affiliations of each result
result_affiliation = spark.read.parquet(path2openAIRE + "result_affiliation").cache()

# And keep only the entries that correspond to FR located organizations
FR_result_affiliation = result_affiliation.join(FR_organizations, on = "organization", how="inner")

# Finally, we use this to filter the papers that contain at least one affiliation in the region of interest
cancer_OA_FR = cancer_OA_all.join(FR_result_affiliation, on="id", how="inner").select(["id"]).dropDuplicates()
print('Number of cancer publications in dataset with FR affiliation:', cancer_OA_FR.count())
# Out:
# Number of organization available: 314059
# Number of FR organizations available: 10569
# [Stage 22:==================================================>     (40 + 4) / 44]
# Number of cancer publications in dataset with FR affiliation: 67874

# %%
# 3. Now, for each paper we will collect the list of all affiliation countries (FR and non FR)
all_result_affiliation = result_affiliation.join(organizations, on = "organization", how="inner")
cancer_OA_FR = cancer_OA_FR.join(all_result_affiliation, on = "id", how = "inner")
cancer_OA_FR = cancer_OA_FR.select(["id", "country"]).groupBy("id").agg(F.collect_list("country").alias("countries"))

# %%
# 4. Finally we need to filter publications according to year interval. We add the year to the available info

result_relevantdate = spark.read.parquet(path2openAIRE + "result_relevantdate").drop("type")

# Merge with relevant publications
cancer_OA_FR = cancer_OA_FR.join(result_relevantdate, on="id", how="inner")

# Extract year from subject (with format yyyy-mm-dd)
cancer_OA_FR = cancer_OA_FR.withColumn("year", F.substring(F.col("subject"), 1, 4).cast("integer")).drop("subject")

# Keep only publications in the desired range
cancer_OA_FR = cancer_OA_FR.filter(cancer_OA_FR["year"].isNotNull() & (cancer_OA_FR["year"] >= years[0]) & (cancer_OA_FR["year"] <= years[-1]))

# We now sort in ascending order of year, to keep the most recent date after dropDuplicates
cancer_OA_FR = cancer_OA_FR.orderBy(cancer_OA_FR["year"].asc()).dropDuplicates(["id"])

# %%
# We are done, we just need to rename the dataframe. We show the number of records and structure of the dataframe
OA_selected_publis = cancer_OA_FR.cache()

print('Number of publications that will be used for the analysis:', OA_selected_publis.count())
OA_selected_publis.printSchema()
OA_selected_publis.show(n=10, truncate=120, vertical=True)
# Out:
# Number of publications that will be used for the analysis: 66134
# root
#  |-- id: string (nullable = true)
#  |-- countries: array (nullable = false)
#  |    |-- element: string (containsNull = false)
#  |-- year: integer (nullable = true)
#
# -RECORD 0-------------------------------------------------------------------------------------
#  id        | doi_dedup___::000e600156867c15e1ab7adbabd38b3f
#  countries | [FR, FR, FR, FR, FR, FR, FR, FR, FR, FR]
#  year      | 2018
# -RECORD 1-------------------------------------------------------------------------------------
#  id        | doi_dedup___::0123b86748c2c49c99dbe25d573a3eaf
#  countries | [FR]
#  year      | 2010
# -RECORD 2-------------------------------------------------------------------------------------
#  id        | doi_dedup___::016bc01a6c1a0c19228ea0da2b6166d8
#  countries | [BE, FR]
#  year      | 2002
# -RECORD 3-------------------------------------------------------------------------------------
#  id        | doi_dedup___::0192c8b8bc84249ad8138413d6649344
#  countries | [BE, FR, CH, CH, CH, BE]
#  year      | 2002
# -RECORD 4-------------------------------------------------------------------------------------
#  id        | doi_dedup___::01f02451107dec89c3184cbec775a753
#  countries | [FR, FR]
#  year      | 2014
# -RECORD 5-------------------------------------------------------------------------------------
#  id        | doi_dedup___::02b1051ff781cd5af8d12d9c891bb19a
#  countries | [FR]
#  year      | 2014
# -RECORD 6-------------------------------------------------------------------------------------
#  id        | doi_dedup___::03b85458be1e1364a8b46dd48722ac5f
#  countries | [IL, FR, IL]
#  year      | 2006
# -RECORD 7-------------------------------------------------------------------------------------
#  id        | doi_dedup___::048c3565b4f8cd30aacac698bb24a383
#  countries | [FR, FR, LB, FR, US, FR, FR, FR]
#  year      | 2017
# -RECORD 8-------------------------------------------------------------------------------------
#  id        | doi_dedup___::04b3e5278abc9e932e017291bfb36371
#  countries | [US, FR, CZ, HR, US, US, FR, US, IE, FR, UNKNOWN, US, UNKNOWN, UNKNOWN, UNKNOWN]
#  year      | 2010
# -RECORD 9-------------------------------------------------------------------------------------
#  id        | doi_dedup___::06bf40ced2ee420f112ac032c970bc9e
#  countries | [FR, NL, IT, FR, FR, FR, FR, FR, US, FR]
#  year      | 2019
# only showing top 10 rows

# %% [markdown]
# ##### Load patents in cancer in EU, necessary for matching in indicator "Publications cited in patents by topic"

# %%
# We select only the patents from the cancer domain
cancer_patents = spark.read.parquet("file:///export/usuarios_ml4ds/jarenas/github/IntelComp/KPIs/WP3-pipelines/datasets/cancer/PATSTAT_DC_Cancer.parquet").select(["appln_id", "appln_auth"])

# We keep only the patents that have presented through the EPO office
cancer_patents_EU = cancer_patents.filter(F.col("appln_auth") == "EP")
cancer_patents_EU = cancer_patents_EU.select("appln_id")

# %%
# We are done, we just need to rename the dataframe. We show the number of records and structure of the dataframe
patstat_target_IND71 = cancer_patents_EU.cache()

print('Number of patents for indicator 7.1.:', patstat_target_IND71.count())
patstat_target_IND71.printSchema()
patstat_target_IND71.show(n=10, truncate=120, vertical=True)
# Out:
# Number of patents for indicator 7.1.: 30509
# root
#  |-- appln_id: string (nullable = true)
#
# -RECORD 0-------------
#  appln_id | 414821201
# -RECORD 1-------------
#  appln_id | 524948270
# -RECORD 2-------------
#  appln_id | 528123678
# -RECORD 3-------------
#  appln_id | 333335694
# -RECORD 4-------------
#  appln_id | 56402702
# -RECORD 5-------------
#  appln_id | 538242950
# -RECORD 6-------------
#  appln_id | 201056
# -RECORD 7-------------
#  appln_id | 575382014
# -RECORD 8-------------
#  appln_id | 184924
# -RECORD 9-------------
#  appln_id | 438322183
# only showing top 10 rows

# %% [markdown]
# ### 1.2. Scientific Production Trends

# %% [markdown]
# #### 1.2.1. Publications over time

# %%
all_years = OA_selected_publis.select("year").rdd.flatMap(lambda x: x).collect()

# %%
all_years.count(2020)
# Out:
# 5782

# %%
year_freq = Counter(all_years)
year = list(year_freq.keys())
freq = list(year_freq.values())
year_freq = sorted([(el1, el2) for el1, el2 in zip(year,freq)], key=lambda x: x[0])

# %%
plt.plot([el[0] for el in year_freq], [el[1] for el in year_freq], 'b-x')

plt.title('Publications over time')
plt.xlabel('year')
plt.ylabel('Publications')

plt.show()

# %% [markdown]
# Description/Source: The graph shows the evolution in the number of publications in the AI domain, in the EU (at least one author is affiliated to an EU organization). Data Source: OpenAIRE Graph

# %%
import pickle

with open(indicators_dir.joinpath("Science_1_1.pickle"), "wb") as fout:
    pickle.dump(year_freq, fout)

# %%
# "i01": "Count of scientific publications"
keys, values = list(zip(*year_freq))

# Save
jstruct.set_info(keys, values, ind="i01", sv="year")
jstruct.save()

# %% [markdown]
# #### 1.2.2. Share of publications in topics over time

# %%
topics_over_time = []

for yr in years:
    print(yr)
    publis_yr = OA_selected_publis.filter(OA_selected_publis["year"] == yr).select("id").rdd.flatMap(lambda x: x).collect()
    publis_yr = set(publis_yr)
    pos = [idx for idx,val in enumerate(corpus_LDA) if val in publis_yr]
    topics_over_time.append(np.sum(thetas_LDA[pos,:], axis=0).tolist()[0])

topics_over_time = np.array(topics_over_time)
# Out:
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020

# %%
import seaborn as sns

cumulative = np.cumsum(topics_over_time, axis=1)

plt.plot(years, cumulative, 'x-')
# Configuración de etiquetas de ejes
plt.xlabel('year')
plt.ylabel('Number of papers')
plt.title('Acumulative number of papers - distribution over topics')
plt.legend(topics_LDA, bbox_to_anchor=(1, 1))

# Mostrar el gráfico
plt.show()

# %%
import seaborn as sns

cumulative = np.cumsum(topics_over_time, axis=1)

plt.plot(years[26:], cumulative[26:,], 'x-')
# Configuración de etiquetas de ejes
plt.xlabel('year')
plt.ylabel('Number of papers')
plt.title('Acumulative number of papers - distribution over topics')
plt.legend(topics_LDA, bbox_to_anchor=(1, 1))

# Mostrar el gráfico
plt.show()

# %%
data = {
    "years" : years,
    "topics_over_time" : topics_over_time,
    "cumulative" : cumulative,
    "topics_LDA" : topics_LDA
}

with open(indicators_dir.joinpath("Science_1_2.pickle"), "wb") as fout:
    pickle.dump(data, fout)

# %%
# Save
jstruct.set_info(keys=topics_LDA, values=topics_over_time.T, ind="i01", sv="topic", years=years)
jstruct.save()

# %% [markdown]
# #### 1.2.3. Open Access publications over time

# %%
results = spark.read.parquet(path2openAIRE + "result")
results = results.drop("dateofcollection").drop("language").drop("type").drop("embargoenddate").drop("dateofacceptance").drop("publisher")
results = results.filter(results["bestaccessrights"] == "Open Access").cache()

selected_open = OA_selected_publis.join(results, on="id", how="inner").dropDuplicates(["id"])
print('Number of Open Access publications', selected_open.count())
# Out:
# 23/11/21 23:24:31 WARN SharedInMemoryCache: Evicting cached table partition metadata from memory due to size constraints (spark.sql.hive.filesourcePartitionFileCacheSize = 262144000 bytes). This may impact query planning performance.
# [Stage 335:===================>                                     (1 + 2) / 3]
# Number of Open Access publications 41703

# %%
all_years = selected_open.select("year").rdd.flatMap(lambda x: x).collect()

# %%
year_freq_open = Counter(all_years)
year = list(year_freq_open.keys())
freq = list(year_freq_open.values())
year_freq_open = sorted([(el1, el2) for el1, el2 in zip(year,freq)], key=lambda x: x[0])

# %%
selected_open_journals = selected_open.filter(selected_open["journal"].isNotNull())
print('Number of Open Access publications (journals only)', selected_open_journals.count())
# Out:
# [Stage 364:===================================================> (183 + 4) / 187]
# Number of Open Access publications (journals only) 25359

# %%
all_years = selected_open_journals.select("year").rdd.flatMap(lambda x: x).collect()

# %%
year_freq_open_journals = Counter(all_years)
year = list(year_freq_open_journals.keys())
freq = list(year_freq_open_journals.values())
year_freq_open_journals = sorted([(el1, el2) for el1, el2 in zip(year,freq)], key=lambda x: x[0])

# %%
plt.bar([el[0] for el in year_freq][20:], [el[1] for el in year_freq][20:])
plt.plot([el[0] for el in year_freq_open][20:], [el[1] for el in year_freq_open][20:],'m-x')
plt.plot([el[0] for el in year_freq_open_journals][20:], [el[1] for el in year_freq_open_journals][20:],'y-x')

plt.title('Open Access Publications over time')
plt.xlabel('year')
plt.ylabel('Number of publications')

plt.legend(["Publications (any type) in Open Access", "Publications in Journals in Open Access", "Publications (total)"])

plt.show()

# %%
plt.bar([el[0] for el in year_freq], [el[1] for el in year_freq])
plt.plot([el[0] for el in year_freq_open], [el[1] for el in year_freq_open],'m-x')
plt.plot([el[0] for el in year_freq_open_journals], [el[1] for el in year_freq_open_journals],'y-x')

plt.title('Open Access Publications over time')
plt.xlabel('year')
plt.ylabel('Number of publications')

plt.legend(["Publications (any type) in Open Access", "Publications in Journals in Open Access", "Publications (total)"])

plt.show()

# %%
data = {
    "year_freq": year_freq,
    "year_freq_open": year_freq_open,
    "year_freq_open_journals": year_freq_open_journals
}

with open(indicators_dir.joinpath("Science_1_3.pickle"), "wb") as fout:
    pickle.dump(data, fout)

# %%
# Save
keys, values = list(zip(*year_freq_open))
jstruct.set_info(keys, values, ind="i23", sv="year")
jstruct.save()

keys, values = list(zip(*year_freq_open_journals))
jstruct.set_info(keys, values, ind="i23b", sv="year")
jstruct.save()

# %% [markdown]
# ### 1.3. Scientific Production Origins

# %% [markdown]
# #### 1.3.1. Publications by Country

# %%
all_countries = OA_selected_publis.select("countries").rdd.flatMap(lambda x: x).collect()

# %%
flat_list = [el for sublist in all_countries for el in sublist]

# %%
country_freq = Counter(flat_list)
country = list(country_freq.keys())
freq = list(country_freq.values())
country_freq = {el1: el2 for el1, el2 in zip(country,freq)}

# %%
with open(indicators_dir.joinpath("Science_2_1.pickle"), "wb") as fout:
    pickle.dump(country_freq, fout)

# %%
# Save
jstruct.set_info(country_freq.keys(), country_freq.values(), ind="i01", sv="country")
jstruct.save()

# %% [markdown]
# #### 1.3.2. Publications by organization (top 100)

# %%
#Load organizations table
organization = spark.read.parquet(path2openAIRE + "organization").withColumnRenamed("id","organization").cache()
#print('Number of organization available:', organization.count())

# Load result_affiliation table
result_affiliation = spark.read.parquet(path2openAIRE + "result_affiliation").cache()
#print('Number of result_affiliation available:', result_affiliation.count())
# Keep only result_affiliation for the relevant papers
result_affiliation = result_affiliation.join(OA_selected_publis, on="id", how="inner").select(["id", "organization"])
# Count only each affiliation once (i.e., no se cuenta múltiples veces si hay varios investigadores de la misma organización)
result_affiliation = result_affiliation.dropDuplicates()

# Replace organization id by organization name
result_affiliation = result_affiliation.join(organization, on="organization", how="inner")
print('Number of organizations in the selected papers:', organization.count())
# Out:
# 23/11/21 23:26:39 WARN CacheManager: Asked to cache already cached data.
# Number of organizations in the selected papers: 314059
# 23/11/21 23:26:40 WARN CacheManager: Asked to cache already cached data.

# %% [markdown]
# Note this number is larger than the number of publications, as one publication can be attributed to more than one organization (but we only count organizations once per paper)

# %%
all_organizations = result_affiliation.select("name").rdd.flatMap(lambda x: x).collect()

organization_freq = Counter(all_organizations)

top100 = organization_freq.most_common(100)

for el, freq in top100:
    print(f"{el}: {freq}")
# Out:
# [Stage 418:============================================>          (20 + 5) / 25]
# Université Paris Diderot: 27175
# Inserm: 25683
# French National Centre for Scientific Research: 6994
# Institut Pasteur: 6066
# Institut Gustave Roussy: 5760
# Paris Descartes University: 4297
# Institute Curie: 3893
# Aix-Marseille University: 3642
# International Agency For Research On Cancer: 3548
# UNIVERSITE PARIS DESCARTES: 3287
# University of Marne la Vallée: 2794
# Sorbonne Paris Cité: 2349
# Assistance Publique -Hopitaux De Paris: 2286
# University of Paris-Sud: 2274
# University of Rennes 1: 1916
# Paris Diderot University: 1896
# Mayo Clinic: 1766
# Harvard University: 1757
# University of Montpellier: 1730
# University of Lyon System: 1709
# University of Bordeaux: 1686
# University of Toulouse: 1527
# University of Strasbourg: 1512
# University of Paris-Saclay: 1490
# University of Copenhagen: 1423
# Claude Bernard University Lyon 1: 1378
# National Institutes of Health: 1363
# Necker-Enfants Malades Hospital: 1342
# Commissariat à l’énergie atomique et aux énergies alternatives: 1334
# Helmholtz Association of German Research Centres: 1291
# University of Oxford: 1206
# University of Cambridge: 1185
# German Cancer Research Center: 1166
# University of Nantes: 1157
# University of Lille: 1142
# Imperial College London: 1120
# The University of Texas MD Anderson Cancer Center: 1025
# KU Leuven: 990
# French Institute for Research in Computer Science and Automation: 952
# French National Institute for Agricultural Research: 900
# Alma Mater Studiorum University of Bologna: 892
# Nice Sophia Antipolis University: 886
# Memorial Sloan Kettering Cancer Center: 880
# Karolinska Institute: 871
# University of Turin: 868
# University of Milan: 847
# Clermont Université: 811
# Utrecht University: 783
# École Normale Supérieure de Lyon: 768
# National and Kapodistrian University of Athens: 754
# Boston Children's Hospital: 739
# University of London: 734
# Institut de Recherche pour le Développement: 710
# École Normale Supérieure: 690
# François Rabelais University: 687
# University of Burgundy: 687
# University Federico II of Naples: 682
# Erasmus University Rotterdam: 664
# University of Barcelona: 660
# Umeå University: 653
# Sapienza University of Rome: 644
# University of Toronto: 641
# University of Mary: 634
# Fred Hutchinson Cancer Research Center: 630
# University of California System: 627
# University of Padua: 617
# Lund University: 599
# INSTITUT GUSTAVE ROUSSY: 596
# Medical University of Vienna: 590
# University of California, San Francisco: 586
# Paul Sabatier University: 585
# University of Zurich: 569
# University of Melbourne: 549
# Joseph Fourier University: 547
# Stanford University: 545
# University of Pennsylvania: 537
# Lille 1 University: 536
# University of Liège: 533
# Heidelberg University: 531
# Université de Caen Normandie: 517
# Aarhus University: 509
# Amsterdam UMC - Vrije Universiteit Amsterdam: 508
# Université Libre de Bruxelles: 507
# University of Lorraine: 501
# University of Geneva: 489
# University of Southern California: 488
# Harvard Medical School: 486
# Icahn School of Medicine at Mount Sinai: 485
# Leiden University Medical Center: 474
# Ludwig-Maximilians-Universität München: 473
# McGill University: 462
# Charité - University Medicine Berlin: 448
# University of Rouen: 443
# University of Salford: 439
# University of California, Los Angeles: 431
# Johns Hopkins University: 425
# University of Amsterdam: 425
# MDPI: 422
# Spanish National Research Council: 420
# University of Helsinki: 417

# %%
orgs = [el for el, _ in top100]
freqs = [freq for _, freq in top100]

plt.figure(figsize=(8, 10)) 
plt.barh(orgs[:30], freqs[:30])

plt.xlabel('Number of papers')
plt.ylabel('Organization')
plt.gca().invert_yaxis()  # Invert y axis

plt.show()

# %%
with open(indicators_dir.joinpath("Science_2_2.pickle"), "wb") as fout:
    pickle.dump(organization_freq, fout)

# %%
# Save
jstruct.set_info(orgs, freqs, ind="i01", sv="organization")
jstruct.save()

# %% [markdown]
# #### 1.3.3. Publications by Funder

# %%
# Load table of acknowledgements, and keep only the ones that are relevant for the selected papers
result_project = spark.read.parquet(path2openAIRE + "result_project")
result_project = result_project.join(OA_selected_publis, on="id", how="inner").select(["id", "project"]).cache()
print('Number of acknowledgments available:', result_project.count())

# Load table of projects and fill in the information regarding the funders of each project
project_funding = spark.read.parquet(path2openAIRE + "project_funding").withColumnRenamed("id","project").cache()
result_funder = result_project.join(project_funding, on="project", how="inner")
# Out:
# [Stage 431:=====================================================> (39 + 1) / 40]
# Number of acknowledgments available: 16634

# %%
all_funders = result_funder.select("funder").rdd.flatMap(lambda x: x).collect()

funders_freq = Counter(all_funders)

top100 = funders_freq.most_common(100)

for el, freq in top100:
    print(f"{el}: {freq}")
# Out:
# [Stage 436:=====================================================> (39 + 1) / 40]
# National Institutes of Health: 6060
# European Commission: 3377
# French National Research Agency (ANR): 1642
# Wellcome Trust: 773
# National Health and Medical Research Council (NHMRC): 636
# Canadian Institutes of Health Research: 403
# Swiss National Science Foundation: 372
# UK Research and Innovation: 324
# Fundação para a Ciência e a Tecnologia, I.P.: 190
# Academy of Finland: 182
# Netherlands Organisation for Scientific Research (NWO): 127
# Natural Sciences and Engineering Research Council of Canada: 118
# National Science Foundation: 90
# Austrian Science Fund (FWF): 66
# Science Foundation Ireland: 30
# Australian Research Council (ARC): 23
# Ministry of Education, Science and Technological Development of Republic of Serbia: 19
# Croatian Science Foundation (CSF): 14
# Ministry of Science, Education and Sports of the Republic of Croatia (MSES): 12
# Social Sciences and Humanities Research Council: 9
# Türkiye Bilimsel ve Teknolojik Araştırma Kurumu: 5
# None: 3
# CHIST-ERA: 2
# Tara Expeditions Foundation: 1

# %%
funder = [el for el, _ in top100]
freqs = [freq for _, freq in top100]

plt.figure(figsize=(8, 10))
plt.barh(funder[:10], freqs[:10])

plt.xlabel('Number of papers')
plt.ylabel('Funding Organization')
plt.gca().invert_yaxis()  # Invert y axis

plt.show()

# %%
with open(indicators_dir.joinpath("Science_2_3.pickle"), "wb") as fout:
    pickle.dump(funders_freq, fout)

# %%
# Save
jstruct.set_info(funder, freqs, ind="i01", sv="funder")
jstruct.save()

# %% [markdown]
# ### 1.4. Scientific Production Characteristics

# %% [markdown]
# #### 1.4.1. Top 50 Journals

# %%
result = spark.read.parquet(path2openAIRE + "result").cache()
result = result.filter(F.col("journal").isNotNull())

# Keep only result results in the selected target dataset
result = result.join(OA_selected_publis, on="id", how="inner")

print('Number of results in journals:', result.count())
# Out:
# [Stage 449:====================================================>(186 + 1) / 187]
# Number of results in journals: 43508

# %%
all_journals = result.select("journal").rdd.flatMap(lambda x: x).collect()

journals_freq = Counter(all_journals)

top100 = journals_freq.most_common(100)

for el, freq in top100:
    print(f"{el}: {freq}")
# Out:
# [Stage 463:===================================================> (183 + 4) / 187]
# PLoS ONE: 796
# Oncogene: 774
# Blood: 630
# British Journal of Cancer: 506
# European journal of cancer (Oxford, England : 1990): 361
# European Journal of Cancer: 340
# International Journal of Cancer: 318
# Oncotarget: 314
# Leukemia: 306
# Annals of Oncology: 281
# Cancers: 271
# Annals of oncology : official journal of the European Society for Medical Oncology: 251
# BMC Cancer: 243
# International journal of cancer: 231
# Journal of Biological Chemistry: 225
# Scientific Reports: 221
# Cancer Research: 211
# Frontiers in Immunology: 208
# Cancer research: 204
# PloS one: 200
# The Journal of biological chemistry: 184
# The Journal of Immunology: 170
# Journal of immunology (Baltimore, Md. : 1950): 166
# Journal of Clinical Oncology: 165
# Carcinogenesis: 155
# Cancer: 152
# Clinical cancer research : an official journal of the American Association for Cancer Research: 152
# Clinical Cancer Research: 150
# International Journal of Molecular Sciences: 148
# Experimental Cell Research: 145
# British journal of cancer: 142
# Experimental cell research: 139
# Nature Communications: 138
# Proceedings of the National Academy of Sciences: 137
# Journal of clinical oncology : official journal of the American Society of Clinical Oncology: 129
# PLOS ONE: 126
# Biochimie: 125
# Haematologica: 122
# Journal of Virology: 121
# OncoImmunology: 114
# The Journal of Clinical Endocrinology &amp; Metabolism: 112
# International journal of radiation oncology, biology, physics: 108
# Frontiers in Oncology: 106
# Radiotherapy and Oncology: 104
# Biochemical and biophysical research communications: 102
# Gastroenterology: 99
# International Journal of Radiation Oncology*Biology*Physics: 98
# Cancer Letters: 98
# Vaccine: 97
# The Journal of clinical endocrinology and metabolism: 96
# Cancer letters: 95
# Bone Marrow Transplantation: 93
# Journal of Hepatology: 90
# Proceedings of the National Academy of Sciences of the United States of America: 90
# Biology of Blood and Marrow Transplantation: 88
# Biochemical and Biophysical Research Communications: 87
# European journal of surgical oncology : the journal of the European Society of Surgical Oncology and the British Association of Surgical Oncology: 86
# Cancer Epidemiology, Biomarkers &amp; Prevention: 85
# Virology: 84
# Critical Reviews in Oncology/Hematology: 83
# Annals of the New York Academy of Sciences: 82
# Journal of Thoracic Oncology: 82
# Lung Cancer: 82
# European Annals of Otorhinolaryngology, Head and Neck Diseases: 81
# European journal of medicinal chemistry: 80
# Critical reviews in oncology/hematology: 80
# Journal of hepatology: 80
# Journal of Investigative Dermatology: 78
# Biochimica et biophysica acta: 78
# Nucleic Acids Research: 78
# FEBS Letters: 77
# Bone marrow transplantation: 76
# Gut: 75
# Stem Cells: 73
# Cancer Epidemiology: 72
# Nature: 70
# Radiotherapy and oncology : journal of the European Society for Therapeutic Radiology and Oncology: 69
# The Oncologist: 69
# The Lancet Oncology: 68
# Lung cancer (Amsterdam, Netherlands): 68
# Leukemialymphoma: 68
# British journal of haematology: 68
# Journal of virology: 67
# Leukemia &amp; Lymphoma: 67
# Cells: 66
# Diagnostic and Interventional Imaging: 66
# Journal of Medicinal Chemistry: 65
# Cancer radiotherapie : journal de la Societe francaise de radiotherapie oncologique: 65
# European Journal of Medicinal Chemistry: 65
# Gynecologic Oncology: 64
# Bioorganicmedicinal chemistry: 63
# Journal of medicinal chemistry: 63
# Cancer epidemiology, biomarkersprevention : a publication of the American Association for Cancer Research, cosponsored by the American Society of Preventive Oncology: 62
# The Lancet. Oncology: 62
# Physics in medicine and biology: 61
# Bioorganic &amp; Medicinal Chemistry: 61
# Cell Cycle: 61
# European Journal of Immunology: 60
# Digestive and liver disease : official journal of the Italian Society of Gastroenterology and the Italian Association for the Study of the Liver: 60
# Medicine: 60

# %%
journal = [el[:40] for el, _ in top100]
freqs = [freq for _, freq in top100]

plt.figure(figsize=(8, 10))  # Ajusta el tamaño del gráfico según tus preferencias
plt.barh(journal[:30], freqs[:30])

# Personaliza el gráfico
plt.xlabel('Number of papers')
plt.ylabel('Journal')
plt.gca().invert_yaxis()  # Invierte el eje y para mostrar los elementos más frecuentes arriba

# Muestra el gráfico
plt.show()

# %%
with open(indicators_dir.joinpath("Science_3_2.pickle"), "wb") as fout:
    pickle.dump(journals_freq, fout)

# %%
# Save
jstruct.set_info(journal, freqs, ind="i01", sv="journal")
jstruct.save()

# %% [markdown]
# ### 1.5. Scientific impact trends

# %% [markdown]
# #### 1.5.1. Publications cited in patents

# %%
# We start loading dois for the selected publications
result_instance_pid = spark.read.parquet(path2openAIRE + "result_instance_pid")
result_instance_pid = result_instance_pid.filter(result_instance_pid["type"] == "Digital Object Identifier")
result_instance_pid = result_instance_pid.select(["result", "pid"]).withColumnRenamed("result","id").withColumnRenamed("pid", "doi")
OA_selected_publis_doi = OA_selected_publis.join(result_instance_pid, on="id", how="inner").cache()

print('Number of publications with dois:',OA_selected_publis_doi.count())
# Out:
# [Stage 476:====================================================>(431 + 1) / 432]
# Number of publications with dois: 103359

# %%
npl_citations = spark.read.parquet(path2PATSTAT + "npl_citations.parquet").select("npl_doi").withColumnRenamed("npl_doi", "doi").cache()
npl_citations = npl_citations.filter(F.col("doi").isNotNull())
print('Number of NPL citations with DOI:', npl_citations.count())
# Out:
# [Stage 480:=====================================================> (49 + 1) / 50]
# Number of NPL citations with DOI: 1938151

# %%
OA_selected_publis_patstat = OA_selected_publis_doi.join(npl_citations, on="doi", how="inner").dropDuplicates(["id"])
print('Number of publications cited in PATSTAT:', OA_selected_publis_patstat.count())
# Out:
# [Stage 488:=================================================>     (26 + 3) / 29]
# Number of publications cited in PATSTAT: 2166

# %%
all_years_npl = OA_selected_publis_patstat.select("year").rdd.flatMap(lambda x: x).collect()

# %%
npl_freq = Counter(all_years_npl)

year = list(npl_freq.keys())
freq = list(npl_freq.values())

npl_freq = sorted([(el1, el2) for el1, el2 in zip(year,freq)], key=lambda x: x[0])

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

ax1.bar([el[0] for el in year_freq], [el[1] for el in year_freq], label="Publications (total)")
ax1.set_xlabel('year')
ax1.set_ylabel('Publications (total)', color='b')
ax1.tick_params('y', colors='b')

ax2.plot([el[0] for el in npl_freq], [el[1] for el in npl_freq], 'g-x', label="Publications cited in patents")
ax2.set_ylabel('Cited in PATSTAT', color='g')
ax2.tick_params('y', colors='g')

plt.title("Publications cited in patents")
plt.show()

# %%
data = {
    "year_freq" : year_freq,
    "npl_freq"  : npl_freq
}

with open(indicators_dir.joinpath("Science_4_1.pickle"), "wb") as fout:
    pickle.dump(data, fout)

# %%
keys, values = list(zip(*npl_freq))

# Save
jstruct.set_info(keys, values, ind="i13a", sv="year")
jstruct.save()

# %% [markdown]
# #### 1.5.2. Total citations over time

# %%
# We extend OA_selected_publis to contain the number of citations for each publication
# We create a dataframe that contains just the ids of the cited papers
result_citations = spark.read.parquet(path2openAIRE + "result_citations").select(["target"]).withColumnRenamed("target", "id")
result_citations = result_citations.join(OA_selected_publis, on="id", how="inner").select(["id"])
# We count the number of citations received by each paper
n_citations = result_citations.groupBy("id").agg(F.count("*").alias("citations"))

# Finally, we merge with the original dataframe with selected publications. We fill with 0s for papers without citations
OA_selected_publis_citations = OA_selected_publis.join(n_citations, on="id", how="left").na.fill(0, subset=["citations"]).cache()

# %%
print('Number of papers:', OA_selected_publis_citations.count())
OA_selected_publis_citations.printSchema()
OA_selected_publis_citations.show(n=2, truncate=120, vertical=True)
# Out:
# [Stage 528:====================================================>(198 + 2) / 200]
# Number of papers: 66134
# root
#  |-- id: string (nullable = true)
#  |-- countries: array (nullable = false)
#  |    |-- element: string (containsNull = false)
#  |-- year: integer (nullable = true)
#  |-- citations: long (nullable = true)
#
# -RECORD 0---------------------------------------------------
#  id        | doi_dedup___::000e600156867c15e1ab7adbabd38b3f
#  countries | [FR, FR, FR, FR, FR, FR, FR, FR, FR, FR]
#  year      | 2018
#  citations | 0
# -RECORD 1---------------------------------------------------
#  id        | doi_dedup___::0123b86748c2c49c99dbe25d573a3eaf
#  countries | [FR]
#  year      | 2010
#  citations | 23
# only showing top 2 rows

# %%
# We aggregate the number of citations per year
sum_citations_df = OA_selected_publis_citations.groupBy("year").agg(F.sum("citations").alias("total_citations"))

# And collect the results in a dictionary
sum_citations_dict = sum_citations_df.rdd.collectAsMap()

# Finally, we create a list with the number of citations per year, sorted according to year
citations_total = []
for el in years:
    if el in sum_citations_dict:
        citations_total.append(sum_citations_dict[el])
    else:
        citations_total.append(0)

# %%
plt.bar(years, citations_total)

plt.title('Total citations over time')
plt.xlabel('year')
plt.ylabel('citations')

plt.show()

# %%
data = {
    "years" : years,
    "citations_total" : citations_total
}

with open(indicators_dir.joinpath("Science_4_3.pickle"), "wb") as fout:
    pickle.dump(data, fout)

# %%
# Save
jstruct.set_info(years, citations_total, ind="i06", sv="year")
jstruct.save()

# %% [markdown]
# #### 1.5.3. Average citations over time

# %%
# We average the number of citations per year
avg_citations_df = OA_selected_publis_citations.groupBy("year").agg(F.avg("citations").alias("average_citations"))

# And collect the results in a dictionary
avg_citations_dict = avg_citations_df.rdd.collectAsMap()

# Finally, we create a list with the number of citations per year, sorted according to year
citations_average = []

for el in years:
    if el in avg_citations_dict:
        citations_average.append(avg_citations_dict[el])
    else:
        citations_average.append(0)

# %%
# Beware there are some elements out of range

plt.bar(years, citations_average)

plt.title('Average citations per publication over time')
plt.xlabel('year')
plt.ylabel('average citations')

plt.show()

# %%
data = {
    "years" : years,
    "citations_average" : citations_average
}

with open(indicators_dir.joinpath("Science_4_2.pickle"), "wb") as fout:
    pickle.dump(data, fout)

# %%
# Save
jstruct.set_info(years, citations_average, ind="i07", sv="year")
jstruct.save()

# %% [markdown]
# ### 1.6. Scientific impact origin

# %% [markdown]
# #### 1.6.1. Total and average number of citations by country

# %%
# We start by generating a new dataframe where each publication is counted separately for each country
citations_country = OA_selected_publis_citations.select(F.explode("countries").alias("country"), "citations").cache()

# %%
# We aggregate the number of citations per country
sum_citations_country_df = citations_country.groupBy("country").agg(F.sum("citations").alias("total_citations"))

# And collect the results in a dictionary
sum_citations_country_dict = sum_citations_country_df.rdd.collectAsMap()

# %%
# For the average we request a minimum number of publications to be taken into account
min_results_per_country = 100

country_counts = citations_country.groupBy("country").agg(F.count("*").alias("count"))
country_keep = country_counts.filter(country_counts["count"] >= min_results_per_country).select(["country"])
citations_country = citations_country.join(country_keep, on = "country", how = "inner")

# We average the number of citations per country
avg_citations_country_df = citations_country.groupBy("country").agg(F.avg("citations").alias("average_citations"))

# And collect the results in a dictionary
avg_citations_country_dict = avg_citations_country_df.rdd.collectAsMap()

# %%
data = {
    "sum_citations_country_dict" : sum_citations_country_dict,
    "avg_citations_country_dict" : avg_citations_country_dict
}

with open(indicators_dir.joinpath("Science_5_1.pickle"), "wb") as fout:
    pickle.dump(data, fout)

# %%
# Save
jstruct.set_info(sum_citations_country_dict.keys(), sum_citations_country_dict.values(), ind="i06", sv="country")
jstruct.save()

# Save
jstruct.set_info(avg_citations_country_dict.keys(), avg_citations_country_dict.values(), ind="i07", sv="country")
jstruct.save()

# %% [markdown]
# #### 1.6.2. Average number of citations per publication by organization (top 100)

# %%
# Load table with all organizations
organization = spark.read.parquet(path2openAIRE + "organization").withColumnRenamed("id","organization")

# We load the list of result_affiliation
result_affiliation = spark.read.parquet(path2openAIRE + "result_affiliation")

# Next to each result and its affiliation, we copy the corresponding number of citations
result_affiliation = result_affiliation.join(OA_selected_publis_citations, on="id", how="inner").select(["organization", "citations"])

# Replace organization id by organization name
result_affiliation = result_affiliation.join(organization, on="organization", how="inner").select(["name", "citations"]).cache()

print('Number of result_affiliation available:', result_affiliation.count())
result_affiliation.printSchema()
result_affiliation.show(n=4, truncate=120, vertical=True)
# Out:
# 23/11/21 23:36:27 WARN CacheManager: Asked to cache already cached data.
# Number of result_affiliation available: 329024
# root
#  |-- name: string (nullable = true)
#  |-- citations: long (nullable = true)
#
# -RECORD 0------------------------------------------------------------------------
#  name      | University of Magdeburg
#  citations | 17
# -RECORD 1------------------------------------------------------------------------
#  name      | ZURICH
#  citations | 0
# -RECORD 2------------------------------------------------------------------------
#  name      | ROYAL INSTITUTION FOR THE ADVANCEMENT OF LEARNING MCGILL UNIVERSITY
#  citations | 0
# -RECORD 3------------------------------------------------------------------------
#  name      | ROYAL INSTITUTION FOR THE ADVANCEMENT OF LEARNING MCGILL UNIVERSITY
#  citations | 27
# only showing top 4 rows

# %%
# We aggregate the number of citations per organization
sum_citations_organization_df = result_affiliation.groupBy("name").agg(F.sum("citations").alias("total_citations"))

# And collect the results in a dictionary
sum_citations_organization_dict = sum_citations_organization_df.rdd.collectAsMap()

# Sort results, and keep only top 100 institutions
sum_citations_organization_dict = sorted([(el[0], el[1]) for el in sum_citations_organization_dict.items()], key=lambda x: -x[1])[:100]

# %%
# For the average we request a minimum number of publications to be taken into account
min_results_per_org = 50

org_counts = result_affiliation.groupBy("name").agg(F.count("*").alias("count"))
org_keep = org_counts.filter(org_counts["count"] >= min_results_per_org).select(["name"])
result_affiliation = result_affiliation.join(org_keep, on = "name", how = "inner")

# We average the number of citations per organization
avg_citations_organization_df = result_affiliation.groupBy("name").agg(F.avg("citations").alias("average_citations"))

# And collect the results in a dictionary
avg_citations_organization_dict = avg_citations_organization_df.rdd.collectAsMap()

# Sort results, and keep only top 100 institutions
avg_citations_organization_dict = sorted([(el[0], el[1]) for el in avg_citations_organization_dict.items()], key=lambda x: -x[1])[:100]

# %%
orgs, freqs = zip(*avg_citations_organization_dict)

plt.figure(figsize=(8, 10))  
plt.barh(orgs[:30], freqs[:30])

plt.xlabel('Citations per organization')
plt.ylabel('Organization')
plt.gca().invert_yaxis()  # Invert y axis

plt.show()

# %%
data = {
    "sum_citations_organization_dict" : sum_citations_organization_dict,
    "avg_citations_organization_dict" : avg_citations_organization_dict
}

with open(indicators_dir.joinpath("Science_5_2.pickle"), "wb") as fout:
    pickle.dump(data, fout)

# %%
# Save average values
jstruct.set_info(orgs, freqs, ind="i07", sv="organization")
jstruct.save()

# Save total values
orgs, freqs = zip(*sum_citations_organization_dict)
jstruct.set_info(orgs, freqs, ind="i06", sv="organization")
jstruct.save()

# %% [markdown]
# #### 1.6.3. Average number of citations per publication by funder

# %%
result_project = spark.read.parquet(path2openAIRE + "result_project")
result_project = result_project.join(OA_selected_publis_citations, on="id", how="inner").select(["project", "citations"])

# Use project id to obtain the funder for each element
project_funding = spark.read.parquet(path2openAIRE + "project_funding").withColumnRenamed("id","project")
result_funder = result_project.join(project_funding, on="project", how="inner").select(["funder", "citations"]).cache()

print('Number of result_funder available:', result_funder.count())
result_funder.printSchema()
result_funder.show(n=4, truncate=120, vertical=True)
# Out:
# Number of result_funder available: 14478
# root
#  |-- funder: string (nullable = true)
#  |-- citations: long (nullable = true)
#
# -RECORD 0------------------------------------------
#  funder    | French National Research Agency (ANR)
#  citations | 35
# -RECORD 1------------------------------------------
#  funder    | French National Research Agency (ANR)
#  citations | 26
# -RECORD 2------------------------------------------
#  funder    | French National Research Agency (ANR)
#  citations | 56
# -RECORD 3------------------------------------------
#  funder    | French National Research Agency (ANR)
#  citations | 19
# only showing top 4 rows

# %%
# We aggregate the number of citations per funder
sum_citations_funder_df = result_funder.groupBy("funder").agg(F.sum("citations").alias("total_citations"))

# And collect the results in a dictionary
sum_citations_funder_dict = sum_citations_funder_df.rdd.collectAsMap()

# Sort results
sum_citations_funder = sorted([(el[0], el[1]) for el in sum_citations_funder_dict.items()], key=lambda x: -x[1])

# %%
# For the average we request a minimum number of publications to be taken into account
min_results_per_funder = 25

funder_counts = result_funder.groupBy("funder").agg(F.count("*").alias("count"))
funder_keep = funder_counts.filter(funder_counts["count"] >= min_results_per_funder).select(["funder"])
result_funder = result_funder.join(funder_keep, on = "funder", how = "inner")

# We average the number of citations per funder
avg_citations_funder_df = result_funder.groupBy("funder").agg(F.avg("citations").alias("average_citations"))

# And collect the results in a dictionary
avg_citations_funder_dict = avg_citations_funder_df.rdd.collectAsMap()

# Sort results
avg_citations_funder = sorted([(el[0], el[1]) for el in avg_citations_funder_dict.items()], key=lambda x: -x[1])

# %%
funder, freqs = zip(*avg_citations_funder)

plt.figure(figsize=(8, 10))  
plt.barh(funder[:30], freqs[:30])

plt.xlabel('Citations per funder')
plt.ylabel('Funder')
plt.gca().invert_yaxis()  # Invert y axis

plt.show()

# %%
data = {
    "sum_citations_funder_dict" : sum_citations_funder_dict,
    "avg_citations_funder_dict" : avg_citations_funder_dict
}

with open(indicators_dir.joinpath("Science_5_3.pickle"), "wb") as fout:
    pickle.dump(data, fout)

# %%
# Save average values
jstruct.set_info(funder, freqs, ind="i07", sv="funder")
jstruct.save()

# Save total values
funder, freqs = zip(*sum_citations_funder)
jstruct.set_info(funder, freqs, ind="i06", sv="funder")
jstruct.save()

# %% [markdown]
# ### 1.7. Scientific impact characteristics

# %% [markdown]
# #### 1.7.1. Publications cited in patents by topic

# %%
# We can start from the OA_selOA_selected_publis_patstat dataframe, but according to the description of
# the indicator, both the publication and the patent where it is cited have to be in the domain and geographic context
# The target set of patents needs to be computed specific for each report (See e.g. Sec. 1.1.1.)

OA_selected_publis_patstat.printSchema()
patstat_target_IND71.printSchema()
# Out:
# root
#  |-- doi: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- countries: array (nullable = false)
#  |    |-- element: string (containsNull = false)
#  |-- year: integer (nullable = true)
#
# root
#  |-- appln_id: string (nullable = true)

# %%
# Therefore, we need to keep only a subset of the publications in OA_selected_publis_patstat
# We keep only those publications associated to patents in patstat_target_IND71

npl_citations = spark.read.parquet(path2PATSTAT + "npl_citations.parquet").select(["appln_id", "npl_doi"]).withColumnRenamed("npl_doi", "doi")
npl_citations = npl_citations.filter(F.col("doi").isNotNull())
npl_citations = npl_citations.join(patstat_target_IND71, on="appln_id", how="inner")

OA_selected_publis_patstat_IND71 = OA_selected_publis_patstat.join(npl_citations, on="doi", how="inner").dropDuplicates(["id"]).cache()

print("Number of publications that are used for Publications cited in patents by topic:", OA_selected_publis_patstat_IND71.count())
OA_selected_publis_patstat_IND71.printSchema()
# Out:
# [Stage 807:=====================================================> (49 + 1) / 50]
# Number of publications that are used for Publications cited in patents by topic: 748
# root
#  |-- doi: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- countries: array (nullable = false)
#  |    |-- element: string (containsNull = false)
#  |-- year: integer (nullable = true)
#  |-- appln_id: string (nullable = true)

# %%
# We calculate the distribution of topics in this subste of publications
relevant_publis = OA_selected_publis_patstat_IND71.select("id").rdd.flatMap(lambda x: x).collect()
relevant_publis = set(relevant_publis)
pos = [idx for idx,val in enumerate(corpus_LDA) if val in relevant_publis]
publis_per_topic = np.sum(thetas_LDA[pos,:], axis=0).tolist()[0]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 10)) 
plt.barh(topics_LDA, publis_per_topic)

plt.xlabel('Number of publications')
plt.ylabel('Topic')
plt.gca().invert_yaxis()  # Invert y axis
plt.show()

# %%
publis_in_patents_topic = {
    'topics_LDA' : topics_LDA,
    'publis_per_topic' : publis_per_topic
}

with open(indicators_dir.joinpath("Science_6_1.pickle"), "wb") as fout:
    pickle.dump(publis_in_patents_topic, fout)

# %%
# Save
jstruct.set_info(topics_LDA, publis_per_topic, ind="i13a", sv="topic")
jstruct.save()

# %% [markdown]
# #### 1.7.2. Citations per publication by topic

# %%
cit_counts_diccio = OA_selected_publis_citations.select("id", "citations").rdd.collectAsMap()

# %%
pos = []
counts = []

for idx,val in enumerate(corpus_LDA):
    if val in cit_counts_diccio:
        pos.append(idx)
        counts.append(cit_counts_diccio[val])

# %%
publis_per_topic = np.sum(thetas_LDA[pos,:], axis=0).tolist()[0]
av_cit_topic = (np.array(counts)*thetas_LDA[pos,:])/np.array(publis_per_topic)

# %%
plt.figure(figsize=(8, 10)) 
plt.barh(topics_LDA, av_cit_topic)

plt.xlabel('Average citations')
plt.ylabel('Topic')
plt.gca().invert_yaxis() 

plt.show()

# %%
av_citations_data = {
    'topics_LDA' : topics_LDA,
    'av_cit_topic' : av_cit_topic
}

with open(indicators_dir.joinpath("Science_6_2.pickle"), "wb") as fout:
    pickle.dump(av_citations_data, fout)

# %%
# Save
jstruct.set_info(topics_LDA, av_cit_topic, ind="i07", sv="topic")
jstruct.save()

# %% [markdown]
# ### 1.8. Scientific impact collaborations

# %% [markdown]
# #### 1.8.1. International Collaborations over time

# %%
# User defined function to count number of different countries in each publication
def filter_and_remove_duplicates(array):
    return len(set(filter(lambda x: x != "UNKNOWN", array)))

filter_and_remove_duplicates_udf = F.udf(filter_and_remove_duplicates, IntegerType())

# Count different countries in each publication
OA_selected_publis_citations = OA_selected_publis_citations.withColumn("n_countries", filter_and_remove_duplicates_udf(F.col("countries")))

# %%
# Count number of multicountry publications
all_years = OA_selected_publis_citations.select("year").rdd.flatMap(lambda x: x).collect()

# Count number of multicountry publications
OA_multicountry = OA_selected_publis_citations.filter(OA_selected_publis_citations["n_countries"] > 1)
all_years_multicountry = OA_multicountry.select("year").rdd.flatMap(lambda x: x).collect()

# Count now only those publications that have been cited
OA_multicountry_cited = OA_multicountry.filter(OA_multicountry["citations"] > 0)
all_years_multicountry_cit = OA_multicountry_cited.select("year").rdd.flatMap(lambda x: x).collect()

# %%
year_freq = Counter(all_years)
year = list(year_freq.keys())
freq = list(year_freq.values())
all_years = sorted([(el1, el2) for el1, el2 in zip(year,freq)], key=lambda x: x[0])

year_freq = Counter(all_years_multicountry)
year = list(year_freq.keys())
freq = list(year_freq.values())
all_years_multicountry = sorted([(el1, el2) for el1, el2 in zip(year,freq)], key=lambda x: x[0])

year_freq = Counter(all_years_multicountry_cit)
year = list(year_freq.keys())
freq = list(year_freq.values())
all_years_multicountry_cit = sorted([(el1, el2) for el1, el2 in zip(year,freq)], key=lambda x: x[0])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot([el[0] for el in all_years_multicountry], [el[1] for el in all_years_multicountry],'y-x')
plt.plot([el[0] for el in all_years_multicountry_cit], [el[1] for el in all_years_multicountry_cit],'m-x')
plt.bar([el[0] for el in all_years], [el[1] for el in all_years])

plt.title('International collaborations over time')
plt.xlabel('year')
plt.ylabel('Number of publications')

plt.legend(["International co-publications", "Citable international co-publications", "Publications over time"])

plt.show()

# %%
intl_colab = {
    'all_years' : all_years,
    'all_years_multicountry' : all_years_multicountry,
    'all_years_multicountry_cit': all_years_multicountry_cit
}

with open(indicators_dir.joinpath("Science_7.1.pickle"), "wb") as fout:
    pickle.dump(intl_colab, fout)

# %%
# "i19": "Number of International co-publications"
keys, values = list(zip(*all_years_multicountry))

# Save
jstruct.set_info(keys, values, ind="i19", sv="year")
jstruct.save()

# "i20": "Number of cited international co-publications"
keys, values = list(zip(*all_years_multicountry_cit))

# Save
jstruct.set_info(keys, values, ind="i20", sv="year")
jstruct.save()

# %% [markdown]
# #### 1.8.2. International collaborations by topic

# %%
OA_multicountry_ids = OA_multicountry.select("id").rdd.flatMap(lambda x: x).collect()
relevant_publis = set(OA_multicountry_ids)
pos = [idx for idx,val in enumerate(corpus_LDA) if val in relevant_publis]
publis_per_topic = np.sum(thetas_LDA[pos,:], axis=0).tolist()[0]

# %%
plt.figure(figsize=(8, 10))
plt.barh(topics_LDA, publis_per_topic)

plt.xlabel('Number of publications')
plt.ylabel('Topic')
plt.title('International collaborations by topic')
plt.gca().invert_yaxis()  # Invert axis

plt.show()

# %%
data = {
    "topics_LDA": topics_LDA,
    "publis_per_topic" : publis_per_topic
}

with open(indicators_dir.joinpath("Science_7.2.pickle"), "wb") as fout:
    pickle.dump(data, fout)

# %%
# Save
jstruct.set_info(topics_LDA, publis_per_topic, ind="i19", sv="topic")
jstruct.save()
# Out:
# I1122 12:46:55.382896 20039 detector.cpp:152] Detected a new leader: (id='10927')
# I1122 12:46:55.382987 20062 group.cpp:700] Trying to get '/mesos/json.info_0000010927' in ZooKeeper
# I1122 12:46:55.383558 20070 zookeeper.cpp:262] A new leading master (UPID=master@10.0.12.77:5050) is detected
# I1122 12:46:55.383720 20069 sched.cpp:345] New master detected at master@10.0.12.77:5050
# I1122 12:46:55.383824 20069 sched.cpp:410] Authenticating with master master@10.0.12.77:5050
# I1122 12:46:55.383829 20069 sched.cpp:417] Using default CRAM-MD5 authenticatee
# I1122 12:46:55.383877 20041 authenticatee.cpp:121] Creating new client SASL connection
# I1122 12:47:01.380590 20060 detector.cpp:152] Detected a new leader: (id='10928')
# I1122 12:47:01.380645 20068 group.cpp:700] Trying to get '/mesos/json.info_0000010928' in ZooKeeper
# I1122 12:47:01.381573 20068 zookeeper.cpp:262] A new leading master (UPID=master@10.0.12.76:5050) is detected
# I1122 12:47:01.381631 20068 sched.cpp:345] New master detected at master@10.0.12.76:5050
# I1122 12:47:01.381892 20049 sched.cpp:488] Failed to authenticate with master master@10.0.12.76:5050: master changed
# I1122 12:47:01.381909 20049 sched.cpp:410] Authenticating with master master@10.0.12.76:5050
# I1122 12:47:01.381913 20049 sched.cpp:417] Using default CRAM-MD5 authenticatee
# I1122 12:47:01.381963 20064 authenticatee.cpp:121] Creating new client SASL connection
# I1122 12:47:07.380410 20071 detector.cpp:152] Detected a new leader: (id='10929')
# I1122 12:47:07.380455 20071 group.cpp:700] Trying to get '/mesos/json.info_0000010929' in ZooKeeper
# I1122 12:47:07.381250 20071 zookeeper.cpp:262] A new leading master (UPID=master@10.0.12.75:5050) is detected
# I1122 12:47:07.381306 20071 sched.cpp:345] New master detected at master@10.0.12.75:5050
# I1122 12:47:07.381487 20055 sched.cpp:488] Failed to authenticate with master master@10.0.12.75:5050: master changed
# I1122 12:47:07.381498 20055 sched.cpp:410] Authenticating with master master@10.0.12.75:5050
# I1122 12:47:07.381501 20055 sched.cpp:417] Using default CRAM-MD5 authenticatee
# I1122 12:47:07.381553 20061 authenticatee.cpp:121] Creating new client SASL connection
# W1122 12:47:14.981853 20079 sched.cpp:455] Authentication timed out
# I1122 12:47:14.981981 20050 sched.cpp:488] Failed to authenticate with master master@10.0.12.75:5050: Authentication discarded
# I1122 12:47:14.982002 20050 sched.cpp:410] Authenticating with master master@10.0.12.75:5050
# I1122 12:47:14.982004 20050 sched.cpp:417] Using default CRAM-MD5 authenticatee
# I1122 12:47:14.982043 20050 authenticatee.cpp:121] Creating new client SASL connection
# I1122 12:47:17.390259 20061 detector.cpp:152] Detected a new leader: (id='10930')
# I1122 12:47:17.390295 20061 group.cpp:700] Trying to get '/mesos/json.info_0000010930' in ZooKeeper
# I1122 12:47:17.391753 20061 zookeeper.cpp:262] A new leading master (UPID=master@10.0.12.18:5050) is detected
# I1122 12:47:17.391875 20067 sched.cpp:345] New master detected at master@10.0.12.18:5050
# I1122 12:47:17.392074 20067 sched.cpp:488] Failed to authenticate with master master@10.0.12.18:5050: master changed
# I1122 12:47:17.392079 20067 sched.cpp:410] Authenticating with master master@10.0.12.18:5050
# I1122 12:47:17.392081 20067 sched.cpp:417] Using default CRAM-MD5 authenticatee
# I1122 12:47:17.392117 20058 authenticatee.cpp:121] Creating new client SASL connection
# I1122 12:47:23.396063 20060 detector.cpp:152] Detected a new leader: (id='10931')
# I1122 12:47:23.396109 20060 group.cpp:700] Trying to get '/mesos/json.info_0000010931' in ZooKeeper
# I1122 12:47:23.397666 20060 zookeeper.cpp:262] A new leading master (UPID=master@10.0.12.78:5050) is detected
# I1122 12:47:23.397706 20051 sched.cpp:345] New master detected at master@10.0.12.78:5050
# I1122 12:47:23.397826 20051 sched.cpp:488] Failed to authenticate with master master@10.0.12.78:5050: master changed
# I1122 12:47:23.397831 20051 sched.cpp:410] Authenticating with master master@10.0.12.78:5050
# I1122 12:47:23.397833 20051 sched.cpp:417] Using default CRAM-MD5 authenticatee
# I1122 12:47:23.397871 20063 authenticatee.cpp:121] Creating new client SASL connection
# W1122 12:47:36.746377 20079 sched.cpp:455] Authentication timed out
# I1122 12:47:36.746464 20070 sched.cpp:488] Failed to authenticate with master master@10.0.12.78:5050: Authentication discarded
# I1122 12:47:36.746497 20070 sched.cpp:410] Authenticating with master master@10.0.12.78:5050
# I1122 12:47:36.746500 20070 sched.cpp:417] Using default CRAM-MD5 authenticatee
# I1122 12:47:36.746554 20068 authenticatee.cpp:121] Creating new client SASL connection
# W1122 12:47:36.747736 20079 process.cpp:846] Failed to recv on socket 503 to peer '192.168.151.139:36718': Decoder error
# I1122 12:47:36.748230 20045 authenticatee.cpp:213] Received SASL authentication mechanisms: CRAM-MD5
# I1122 12:47:36.748250 20045 authenticatee.cpp:239] Attempting to authenticate with mechanism 'CRAM-MD5'
# I1122 12:47:36.748677 20054 authenticatee.cpp:259] Received SASL authentication step
# I1122 12:47:36.749042 20073 authenticatee.cpp:299] Authentication success
# I1122 12:47:36.749105 20075 sched.cpp:522] Successfully authenticated with master master@10.0.12.78:5050
# I1122 12:47:36.749675 20060 sched.cpp:753] Framework registered with 1e800c9c-541d-4056-8c7b-1cb2b8cd2347-0022

# %% [markdown]
# ## 2. Technology indicators

# %% [markdown]
# ### 2.1. Load data for Analysis and Topic Model

# %% [markdown]
# #### 2.1.1. Artificial intelligence in EU

# %%
# Prepare structure for exporting the results

domain = "AI"
geography = "EU"
pv = "AI"

years = [el for el in range(1990, 2021)]

indicators_dir = Path("/export/usuarios_ml4ds/jarenas/github/IntelComp/KPIs/WP3-pipelines/indicators/AI/EU/Technology")
jstruct = JSONstruct(domain, geography, pv, indicators_dir)

# %% [markdown]
# ##### Load Topic Model variables

# %%
# Load topic model variables
path2model = "/export/usuarios_ml4ds/jarenas/github/IntelComp/ITMT/topicmodeler/WP6models/TMmodels/PATSTAT_Kwds3_AI_25tpc/"

with open(path2model + "corpus.txt") as fin:
    corpus_LDA = [el.split()[0].strip() for el in fin.readlines()]

thetas_LDA = sparse.load_npz(path2model + "TMmodel/thetas.npz")

with open(path2model + "TMmodel/tpc_labels.txt") as fin:
    topics_LDA = [el.strip() for el in fin.readlines()]

# %% [markdown]
# ##### Load relevant patents from the AI domain from the EPO

# %%
# 1. Load all patents in AI
AI_patents_file = "file:///export/usuarios_ml4ds/jarenas/github/IntelComp/KPIs/WP3-pipelines/datasets/AI/PATSTAT_Kwds3_AI.parquet"
AI_patents_all = spark.read.parquet(AI_patents_file)

print('Number of patents with AI keywords:', AI_patents_all.count())

# 2. We keep only the patents that have been granted, and those presented through the EPO
AI_patents_granted = AI_patents_all.filter(F.col("granted") == "Y")
AI_patents_EU = AI_patents_granted.filter(F.col("appln_auth") == "EP")
print('Number of AI patents granted by EPO:', AI_patents_EU.count())

# 3. Finally we need to filter publications according to year interval. We add the year to the available info
AI_patents_EU = AI_patents_EU.withColumn("earliest_filing_year", F.col("earliest_filing_year").cast(IntegerType()))
AI_patents_EU = AI_patents_EU.filter(AI_patents_EU["earliest_filing_year"].isNotNull() & (AI_patents_EU["earliest_filing_year"] >= years[0]) & (AI_patents_EU["earliest_filing_year"] <= years[-1]))
# Out:
# Number of patents with AI keywords: 146022
# [Stage 1072:=================================================>    (37 + 3) / 40]
# Number of AI patents granted by EPO: 1113

# %%
# We are done, we just need to rename the dataframe. We show the number of records and structure of the dataframe
PATSTAT_selected = AI_patents_EU.cache()

print('Number of patents that will be used for the analysis:', PATSTAT_selected.count())
PATSTAT_selected.printSchema()
PATSTAT_selected.show(n=10, truncate=120, vertical=True)
# Out:
# Number of patents that will be used for the analysis: 1044
# root
#  |-- appln_id: string (nullable = true)
#  |-- docdb_family_id: string (nullable = true)
#  |-- appln_title: string (nullable = true)
#  |-- appln_title_lg: string (nullable = true)
#  |-- appln_abstract: string (nullable = true)
#  |-- appln_abstract_lg: string (nullable = true)
#  |-- appln_filing_year: string (nullable = true)
#  |-- earliest_filing_year: integer (nullable = true)
#  |-- granted: string (nullable = true)
#  |-- appln_auth: string (nullable = true)
#  |-- receiving_office: string (nullable = true)
#  |-- ipr_type: string (nullable = true)
#  |-- Kwd_count: integer (nullable = true)
# -RECORD 0----------------------------------------------------------------------------------------------------------------------------------------
#  appln_id             | 274101009
#  docdb_family_id      | 41479094
#  appln_title          | METHOD FOR ANALYZING MESSAGE ARCHIVES AND CORRESPONDING COMPUTER PROGRAM TO GENERATE A FINITE STATES MACHINE
#  appln_title_lg       | en
#  appln_abstract       | The invention relates to a method for analyzing a large number of messages (28), wherein the number of messages is re...
#  appln_abstract_lg    | en
#  appln_filing_year    | 2009
#  earliest_filing_year | 2009
#  granted              | Y
#  appln_auth           | EP
#  receiving_office     |
#  ipr_type             | PI
#  Kwd_count            | 4
# -RECORD 1----------------------------------------------------------------------------------------------------------------------------------------
#  appln_id             | 417260810
#  docdb_family_id      | 50513489
#  appln_title          | MANAGING COMPUTER SERVER CAPACITY
#  appln_title_lg       | en
#  appln_abstract       | Systems and methods are disclosed for using machine learning (e.g., neural networks and/or combinatorial learning) to...
#  appln_abstract_lg    | en
#  appln_filing_year    | 2014
#  earliest_filing_year | 2013
#  granted              | Y
#  appln_auth           | EP
#  receiving_office     |
#  ipr_type             | PI
#  Kwd_count            | 4
# -RECORD 2----------------------------------------------------------------------------------------------------------------------------------------
#  appln_id             | 449493542
#  docdb_family_id      | 55411207
#  appln_title          | ELECTRONIC DEVICE AND METHOD OF OPERATING VOICE RECOGNITION FUNCTION
#  appln_title_lg       | en
#  appln_abstract       | Provided is an electronic device that includes a first processor for receiving an audio signal, performing first voic...
#  appln_abstract_lg    | en
#  appln_filing_year    | 2016
#  earliest_filing_year | 2015
#  granted              | Y
#  appln_auth           | EP
#  receiving_office     |
#  ipr_type             | PI
#  Kwd_count            | 5
# -RECORD 3----------------------------------------------------------------------------------------------------------------------------------------
#  appln_id             | 315729168
#  docdb_family_id      | 36142269
#  appln_title          | Speech recognition
#  appln_title_lg       | en
#  appln_abstract       | The invention provides a system and method for improving speech recognition. A computer software system is provided f...
#  appln_abstract_lg    | en
#  appln_filing_year    | 2005
#  earliest_filing_year | 2004
#  granted              | Y
#  appln_auth           | EP
#  receiving_office     |
#  ipr_type             | PI
#  Kwd_count            | 5
# -RECORD 4----------------------------------------------------------------------------------------------------------------------------------------
#  appln_id             | 476787953
#  docdb_family_id      | 64332430
#  appln_title          | A METHOD FOR MOTION CLASSIFICATION USING A PULSED RADAR SYSTEM
#  appln_title_lg       | en
#  appln_abstract       | With the present invention, there is provided a method for classification of the motion of a moving target by means o...
#  appln_abstract_lg    | en
#  appln_filing_year    | 2017
#  earliest_filing_year | 2016
#  granted              | Y
#  appln_auth           | EP
#  receiving_office     |
#  ipr_type             | PI
#  Kwd_count            | 4
# -RECORD 5----------------------------------------------------------------------------------------------------------------------------------------
#  appln_id             | 16420365
#  docdb_family_id      | 39592581
#  appln_title          | Language understanding device
#  appln_title_lg       | en
#  appln_abstract       | A language understanding device includes: a language understanding model storing unit (10, 210) configured to store w...
#  appln_abstract_lg    | en
#  appln_filing_year    | 2008
#  earliest_filing_year | 2007
#  granted              | Y
#  appln_auth           | EP
#  receiving_office     |
#  ipr_type             | PI
#  Kwd_count            | 4
# -RECORD 6----------------------------------------------------------------------------------------------------------------------------------------
#  appln_id             | 16115268
#  docdb_family_id      | 34929569
#  appln_title          | Speech recognition method constrained with a grammar received from a remote system.
#  appln_title_lg       | en
#  appln_abstract       | A speech recognition method for recognizing a word input in a speaker equipment (1), comprising the steps of: determi...
#  appln_abstract_lg    | en
#  appln_filing_year    | 2004
#  earliest_filing_year | 2004
#  granted              | Y
#  appln_auth           | EP
#  receiving_office     |
#  ipr_type             | PI
#  Kwd_count            | 3
# -RECORD 7----------------------------------------------------------------------------------------------------------------------------------------
#  appln_id             | 440612006
#  docdb_family_id      | 53284027
#  appln_title          | IMAGE RECOGNITION DEVICE AND METHOD FOR REGISTERING FEATURE DATA IN IMAGE RECOGNITION DEVICE
#  appln_title_lg       | en
#  appln_abstract       | Provided is a technology of suppressing degradation of distinguishability from another object when new feature data i...
#  appln_abstract_lg    | en
#  appln_filing_year    | 2015
#  earliest_filing_year | 2014
#  granted              | Y
#  appln_auth           | EP
#  receiving_office     |
#  ipr_type             | PI
#  Kwd_count            | 3
# -RECORD 8----------------------------------------------------------------------------------------------------------------------------------------
#  appln_id             | 306989
#  docdb_family_id      | 34939425
#  appln_title          | Intelligent automatic Form-Filling
#  appln_title_lg       | en
#  appln_abstract       | The present invention provides a unique system and method that can employ machine learning techniques to automaticall...
#  appln_abstract_lg    | en
#  appln_filing_year    | 2005
#  earliest_filing_year | 2004
#  granted              | Y
#  appln_auth           | EP
#  receiving_office     |
#  ipr_type             | PI
#  Kwd_count            | 3
# -RECORD 9----------------------------------------------------------------------------------------------------------------------------------------
#  appln_id             | 480144367
#  docdb_family_id      | 59034873
#  appln_title          | MEMORY-EFFICIENT BACKPROPAGATION THROUGH TIME
#  appln_title_lg       | en
#  appln_abstract       | Methods, systems, and apparatus, including computer programs encoded on a computer storage medium, for training a rec...
#  appln_abstract_lg    | en
#  appln_filing_year    | 2017
#  earliest_filing_year | 2016
#  granted              | Y
#  appln_auth           | EP
#  receiving_office     |
#  ipr_type             | PI
#  Kwd_count            | 3
# only showing top 10 rows

# %% [markdown]
# #### 2.1.2. Cancer in EU

# %%
# Prepare structure for exporting the results

domain = "Cancer"
geography = "EU"
pv = "Cancer"

years = [el for el in range(1990, 2021)]

indicators_dir = Path("/export/usuarios_ml4ds/jarenas/github/IntelComp/KPIs/WP3-pipelines/indicators/Cancer/EU/Technology")
jstruct = JSONstruct(domain, geography, pv, indicators_dir)

# %% [markdown]
# ##### Load Topic Model variables

# %%
# Load topic model variables
path2model = "/export/usuarios_ml4ds/jarenas/github/IntelComp/ITMT/topicmodeler/WP6models/TMmodels/PATSTAT_DC_Cancer_20tpc/"

with open(path2model + "corpus.txt") as fin:
    corpus_LDA = [el.split()[0].strip() for el in fin.readlines()]

thetas_LDA = sparse.load_npz(path2model + "TMmodel/thetas.npz")

with open(path2model + "TMmodel/tpc_labels.txt") as fin:
    topics_LDA = [el.strip() for el in fin.readlines()]

# %% [markdown]
# ##### Load relevant patents from the Cancer domain from the EPO

# %%
# 1. Load all patents in AI
cancer_patents_file = "file:///export/usuarios_ml4ds/jarenas/github/IntelComp/KPIs/WP3-pipelines/datasets/cancer/PATSTAT_DC_Cancer.parquet"
cancer_patents_all = spark.read.parquet(cancer_patents_file)

print('Number of patents related to cancer (DC):', cancer_patents_all.count())

# 2. We keep only the patents that have been granted, and those presented through the EPO
cancer_patents_granted = cancer_patents_all.filter(F.col("granted") == "Y")
cancer_patents_EU = cancer_patents_granted.filter(F.col("appln_auth") == "EP")
print('Number of cancer patents granted by EPO:', cancer_patents_EU.count())

# 3. Finally we need to filter publications according to year interval. We add the year to the available info
cancer_patents_EU = cancer_patents_EU.withColumn("earliest_filing_year", F.col("earliest_filing_year").cast(IntegerType()))
cancer_patents_EU = cancer_patents_EU.filter(cancer_patents_EU["earliest_filing_year"].isNotNull() & (cancer_patents_EU["earliest_filing_year"] >= years[0]) & (cancer_patents_EU["earliest_filing_year"] <= years[-1]))
# Out:
# Number of patents related to cancer (DC): 213405
# Number of cancer patents granted by EPO: 10106

# %%
# We are done, we just need to rename the dataframe. We show the number of records and structure of the dataframe
PATSTAT_selected = cancer_patents_EU.cache()

print('Number of patents that will be used for the analysis:', PATSTAT_selected.count())
PATSTAT_selected.printSchema()
PATSTAT_selected.show(n=10, truncate=120, vertical=True)
# Out:
# Number of patents that will be used for the analysis: 9819
# root
#  |-- appln_id: string (nullable = true)
#  |-- docdb_family_id: string (nullable = true)
#  |-- appln_title: string (nullable = true)
#  |-- appln_title_lg: string (nullable = true)
#  |-- appln_abstract: string (nullable = true)
#  |-- appln_abstract_lg: string (nullable = true)
#  |-- appln_filing_year: string (nullable = true)
#  |-- earliest_filing_year: integer (nullable = true)
#  |-- granted: string (nullable = true)
#  |-- appln_auth: string (nullable = true)
#  |-- receiving_office: string (nullable = true)
#  |-- ipr_type: string (nullable = true)
#
# -RECORD 0----------------------------------------------------------------------------------------------------------------------------------------
#  appln_id             | 414821201
#  docdb_family_id      | 50028012
#  appln_title          | MONOCLONAL ANTIBODY AGAINST HUMAN MIDKINE
#  appln_title_lg       | en
#  appln_abstract       | A monoclonal antibody, which recognizes at least two amino acids among amino acids located at position 69, position 7...
#  appln_abstract_lg    | en
#  appln_filing_year    | 2013
#  earliest_filing_year | 2012
#  granted              | Y
#  appln_auth           | EP
#  receiving_office     |
#  ipr_type             | PI
# -RECORD 1----------------------------------------------------------------------------------------------------------------------------------------
#  appln_id             | 201056
#  docdb_family_id      | 40048962
#  appln_title          | Method and apparatus for judging the presence or absence of cancer cell
#  appln_title_lg       | en
#  appln_abstract       | The invention provides a method for judging whether cancer cells are present or not in a sample, comprising a obtaini...
#  appln_abstract_lg    | en
#  appln_filing_year    | 2008
#  earliest_filing_year | 2007
#  granted              | Y
#  appln_auth           | EP
#  receiving_office     |
#  ipr_type             | PI
# -RECORD 2----------------------------------------------------------------------------------------------------------------------------------------
#  appln_id             | 191883
#  docdb_family_id      | 26882739
#  appln_title          | USE OF AN ANTIBODY OR AN IMMUNOTOXIN THAT SELECTIVELY BINDS TO CD123 TO IMPAIR HEMATOLOGIC CANCER PROGENITOR CELLS
#  appln_title_lg       | en
#  appln_abstract       | Primitive or progenitor hematologic cancer cells have been implicated in the early stages and development of leukemia...
#  appln_abstract_lg    | en
#  appln_filing_year    | 2001
#  earliest_filing_year | 2000
#  granted              | Y
#  appln_auth           | EP
#  receiving_office     |
#  ipr_type             | PI
# -RECORD 3----------------------------------------------------------------------------------------------------------------------------------------
#  appln_id             | 17354922
#  docdb_family_id      | 26732130
#  appln_title          | CYTOCHROME P450 REDUCTASE FOR THE ENHANCEMENT OF P450-BASED ANTI-CANCER GENE THERAPY
#  appln_title_lg       | en
#  appln_abstract       | Methods of killing neoplastic cells are provided. The invention relates to the use of NADPH-cytochrome P450 reductase...
#  appln_abstract_lg    | en
#  appln_filing_year    | 1998
#  earliest_filing_year | 1997
#  granted              | Y
#  appln_auth           | EP
#  receiving_office     |
#  ipr_type             | PI
# -RECORD 4----------------------------------------------------------------------------------------------------------------------------------------
#  appln_id             | 16168433
#  docdb_family_id      | 34312196
#  appln_title          | HPV CD8+ T-CELL EPITOPES
#  appln_title_lg       | en
#  appln_abstract       | The present invention provides means to identify functional CD8+ T-cell epitopes in any protein of interest. The pres...
#  appln_abstract_lg    | en
#  appln_filing_year    | 2004
#  earliest_filing_year | 2003
#  granted              | Y
#  appln_auth           | EP
#  receiving_office     |
#  ipr_type             | PI
# -RECORD 5----------------------------------------------------------------------------------------------------------------------------------------
#  appln_id             | 456239099
#  docdb_family_id      | 53015749
#  appln_title          | BIOMARKERS FOR DETERMINING THE CLINICAL RESPONSE TO CELL THERAPY
#  appln_title_lg       | en
#  appln_abstract       | The invention relates to a method for predicting the clinical response to a therapy based on the administration of me...
#  appln_abstract_lg    | en
#  appln_filing_year    | 2016
#  earliest_filing_year | 2015
#  granted              | Y
#  appln_auth           | EP
#  receiving_office     |
#  ipr_type             | PI
# -RECORD 6----------------------------------------------------------------------------------------------------------------------------------------
#  appln_id             | 414553718
#  docdb_family_id      | 49998595
#  appln_title          | METHOD FOR THE DIAGNOSIS, PROGNOSIS AND TREATMENT OF PROSTATE CANCER METASTASIS USING C-MAF
#  appln_title_lg       | en
#  appln_abstract       | The present invention relates to a method for the diagnosis or the prognosis of metastasis in prostate cancer which c...
#  appln_abstract_lg    | en
#  appln_filing_year    | 2013
#  earliest_filing_year | 2012
#  granted              | Y
#  appln_auth           | EP
#  receiving_office     |
#  ipr_type             | PI
# -RECORD 7----------------------------------------------------------------------------------------------------------------------------------------
#  appln_id             | 501723402
#  docdb_family_id      | 50630577
#  appln_title          | LNCRNAS FOR THERAPY AND DIAGNOSIS OF CARDIAC HYPERTROPHY
#  appln_title_lg       | en
#  appln_abstract       | The present invention relates to a pharmaceutical composition comprising (i) a compound promoting the expression and/...
#  appln_abstract_lg    | en
#  appln_filing_year    | 2015
#  earliest_filing_year | 2014
#  granted              | Y
#  appln_auth           | EP
#  receiving_office     |
#  ipr_type             | PI
# -RECORD 8----------------------------------------------------------------------------------------------------------------------------------------
#  appln_id             | 418417424
#  docdb_family_id      | 50731151
#  appln_title          | SOLUBLE MEDIATOR
#  appln_title_lg       | en
#  appln_abstract       | The present disclosure relates to the use of a soluble CD52 glycoprotein in treating diseases regulated by effector T...
#  appln_abstract_lg    | en
#  appln_filing_year    | 2013
#  earliest_filing_year | 2012
#  granted              | Y
#  appln_auth           | EP
#  receiving_office     |
#  ipr_type             | PI
# -RECORD 9----------------------------------------------------------------------------------------------------------------------------------------
#  appln_id             | 443382991
#  docdb_family_id      | 51225425
#  appln_title          | RADIO-LABELLED ANTIBODY FRAGMENTS FOR USE IN THE PREVENTION AND/OR TREATMENT OF CANCER
#  appln_title_lg       | en
#  appln_abstract       | The application provides polypeptides comprising or essentially consisting of at least one heavy chain variable domai...
#  appln_abstract_lg    | en
#  appln_filing_year    | 2015
#  earliest_filing_year | 2014
#  granted              | Y
#  appln_auth           | EP
#  receiving_office     |
#  ipr_type             | PI
# only showing top 10 rows

# %% [markdown]
# ### 2.2. Technological Production Trends

# %% [markdown]
# #### 2.2.1. Patents over time

# %%
year_count = PATSTAT_selected.groupBy("earliest_filing_year").agg(F.count("*").alias("counts")).rdd.collectAsMap()
pats_per_year = [year_count[el] for el in years]

# %%
plt.plot(years, pats_per_year, 'b-x')

plt.title('Patents granted by EPO over time')
plt.xlabel('year')
plt.ylabel('Patents')

plt.show()

# %%
data = {
    "years" : years,
    "pats_per_year" : pats_per_year
}

with open(indicators_dir.joinpath("Technology_1_1.pickle"), "wb") as fout:
    pickle.dump(data, fout)

# %%
# Save
jstruct.set_info(years, pats_per_year, ind="i09", sv="year")
jstruct.save()

# %% [markdown]
# #### 2.2.2. Distribution by year of topics in patents to the EPO (by priority year)"

# %%
topics_over_time = []

for yr in years:
    print(yr)
    patents_yr = PATSTAT_selected.filter(PATSTAT_selected["earliest_filing_year"] == yr).select("appln_id").rdd.flatMap(lambda x: x).collect()
    patents_yr = set(patents_yr)
    pos = [idx for idx,val in enumerate(corpus_LDA) if val in patents_yr]
    topics_over_time.append(np.sum(thetas_LDA[pos,:], axis=0).tolist()[0])

topics_over_time = np.array(topics_over_time)
# Out:
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020

# %%
import seaborn as sns

cumulative = np.cumsum(topics_over_time, axis=1)

plt.plot(years, cumulative, 'x-')
# Configuración de etiquetas de ejes
plt.xlabel('year')
plt.ylabel('Patents')
plt.title('Acumulative number of patents - distribution over topics')
plt.legend(topics_LDA, bbox_to_anchor=(1, 1))

# Mostrar el gráfico
plt.show()

# %%
data = {
    "years" : years,
    "topics_over_time" : topics_over_time,
    "cumulative" : cumulative,
    "topics_LDA" : topics_LDA
}

with open(indicators_dir.joinpath("Technology_1_2.pickle"), "wb") as fout:
    pickle.dump(data, fout)

# %%
# Save
jstruct.set_info(keys=topics_LDA, values=topics_over_time.T, ind="i09b", sv="topic", years=years)
jstruct.save()

# %% [markdown]
# ### 2.3. Technological production origins

# %%
# We start enriching the dataset with person information, including harmonized name, country, and sector
tls207 = spark.read.parquet(path2PATSTAT + "tls207.parquet").select(["appln_id", "person_id"])
PATSTAT_selected_person = PATSTAT_selected.join(tls207, on="appln_id", how="left")

tls206 = spark.read.parquet(path2PATSTAT + "tls206.parquet").select(["person_id", "psn_name", "psn_sector", "person_ctry_code"])
PATSTAT_selected_person = PATSTAT_selected_person.join(tls206, on="person_id", how="left").cache()

print("Number of patents incorporating person information:", PATSTAT_selected_person.count())
PATSTAT_selected_person.printSchema()
PATSTAT_selected_person.show(n=4, truncate=120, vertical=True)
# Out:
# [Stage 53:====================================================> (196 + 4) / 200]
# Number of patents incorporating person information: 48492
# root
#  |-- person_id: string (nullable = true)
#  |-- appln_id: string (nullable = true)
#  |-- docdb_family_id: string (nullable = true)
#  |-- appln_title: string (nullable = true)
#  |-- appln_title_lg: string (nullable = true)
#  |-- appln_abstract: string (nullable = true)
#  |-- appln_abstract_lg: string (nullable = true)
#  |-- appln_filing_year: string (nullable = true)
#  |-- earliest_filing_year: integer (nullable = true)
#  |-- granted: string (nullable = true)
#  |-- appln_auth: string (nullable = true)
#  |-- receiving_office: string (nullable = true)
#  |-- ipr_type: string (nullable = true)
#  |-- psn_name: string (nullable = true)
#  |-- psn_sector: string (nullable = true)
#  |-- person_ctry_code: string (nullable = true)
#
# -RECORD 0----------------------------------------------------------------------------------------------------------------------------------------
#  person_id            | 1098706
#  appln_id             | 15852456
#  docdb_family_id      | 27394650
#  appln_title          | HUMAN CYR61
#  appln_title_lg       | en
#  appln_abstract       | Polynucleotides encoding mammalian ECM signaling molecules affecting the cell adhesion, migration, and proliferation ...
#  appln_abstract_lg    | en
#  appln_filing_year    | 2001
#  earliest_filing_year | 2000
#  granted              | Y
#  appln_auth           | EP
#  receiving_office     |
#  ipr_type             | PI
#  psn_name             | MUNIN CORPORATION
#  psn_sector           | COMPANY
#  person_ctry_code     | US
# -RECORD 1----------------------------------------------------------------------------------------------------------------------------------------
#  person_id            | 1124173
#  appln_id             | 15863711
#  docdb_family_id      | 22737985
#  appln_title          | METHOD FOR TREATMENT OF TUMORS USING PHOTODYNAMIC THERAPY
#  appln_title_lg       | en
#  appln_abstract       | A method for treating tumor-bearing subjects that includes administering to the tumor bearing subject a therapeutical...
#  appln_abstract_lg    | en
#  appln_filing_year    | 2001
#  earliest_filing_year | 2000
#  granted              | Y
#  appln_auth           | EP
#  receiving_office     |
#  ipr_type             | PI
#  psn_name             | THOMAS, ELAINE, K.
#  psn_sector           | null
#  person_ctry_code     | US
# -RECORD 2----------------------------------------------------------------------------------------------------------------------------------------
#  person_id            | 1467275
#  appln_id             | 353222841
#  docdb_family_id      | 45952467
#  appln_title          | METHODS FOR SYNTHESIS OF AN OLIGOPEPTIDE MICROARRAY
#  appln_title_lg       | en
#  appln_abstract       | An oligopeptide microarray and methods for the synthesis thereof are presented. Further presented is a microarray on ...
#  appln_abstract_lg    | en
#  appln_filing_year    | 2012
#  earliest_filing_year | 2011
#  granted              | Y
#  appln_auth           | EP
#  receiving_office     |
#  ipr_type             | PI
#  psn_name             | STENGELE, KLAUS-PETER
#  psn_sector           | null
#  person_ctry_code     | DE
# -RECORD 3----------------------------------------------------------------------------------------------------------------------------------------
#  person_id            | 1467276
#  appln_id             | 16053642
#  docdb_family_id      | 30000842
#  appln_title          | CO-ADMINISTRATION OF CG250 AND IL-2 OR IFN-ALPHA FOR TREATING CANCER SUCH AS RENAL CELL CARCINOMAS
#  appln_title_lg       | en
#  appln_abstract       | A method for enhancing the therapeutic effect of cytokine treatment is disclosed. More specifically the present inven...
#  appln_abstract_lg    | en
#  appln_filing_year    | 2003
#  earliest_filing_year | 2002
#  granted              | Y
#  appln_auth           | EP
#  receiving_office     |
#  ipr_type             | PI
#  psn_name             | WARNAAR, SVEN, OLE
#  psn_sector           | null
#  person_ctry_code     | NL
# only showing top 4 rows

# %% [markdown]
# #### 2.3.1. Patents by Country

# %%
PATSTAT_country = PATSTAT_selected_person.filter(PATSTAT_selected_person["person_ctry_code"].isNotNull()).select("person_ctry_code")
country_freq = PATSTAT_country.groupBy("person_ctry_code").agg(F.count("*").alias("counts")).rdd.collectAsMap()

# %%
with open(indicators_dir.joinpath("Technology_2_1.pickle"), "wb") as fout:
    pickle.dump(country_freq, fout)

# %%
# Save
jstruct.set_info(country_freq.keys(), country_freq.values(), ind="i09", sv="country")
jstruct.save()

# %% [markdown]
# #### 2.3.2. Patents by organization (top 100)

# %%
PATSTAT_org = PATSTAT_selected_person.filter(PATSTAT_selected_person["psn_name"].isNotNull()).select("psn_name")
org_freq = PATSTAT_org.groupBy("psn_name").agg(F.count("*").alias("counts")).rdd.collectAsMap()

# %%
# Sort results, and keep only top 100 institutions
org_freq = sorted([(el[0].title(), el[1]) for el in org_freq.items()], key=lambda x: -x[1])[:100]

# %%
orgs, freqs = zip(*org_freq)

plt.figure(figsize=(8, 10))  
plt.barh(orgs[:30], freqs[:30])

plt.xlabel('Number of patents')
plt.ylabel('Organization')
plt.title('Number of patents per organization (top 100)')
plt.gca().invert_yaxis()  # Invert y axis

plt.show()

# %%
data = {
    "orgs" : orgs,
    "freqs" : freqs
}

with open(indicators_dir.joinpath("Technology_2_2.pickle"), "wb") as fout:
    pickle.dump(data, fout)

# %%
# Save
jstruct.set_info(orgs, freqs, ind="i09", sv="organization")
jstruct.save()

# %% [markdown]
# #### 2.3.3. Patents by sector

# %%
PATSTAT_sector = PATSTAT_selected_person.filter(PATSTAT_selected_person["psn_sector"].isNotNull()).filter(PATSTAT_selected_person["psn_sector"]!="UNKNOWN").select("psn_sector")
sector_freq = PATSTAT_sector.groupBy("psn_sector").agg(F.count("*").alias("counts")).rdd.collectAsMap()

# %%
# Sort results
sector_freq  = sorted([(el[0].title(), el[1]) for el in sector_freq.items()], key=lambda x: -x[1])[:100]

# %%
sector, freqs = zip(*sector_freq)

plt.figure(figsize=(8, 10))  
plt.pie(freqs, labels=sector, autopct='%1.1f%%')

plt.xlabel('Number of patents')
plt.ylabel('Sector')
plt.title('Number of patents per sector')
plt.gca().invert_yaxis()  # Invert y axis

plt.show()

# %%
data = {
    "sector" : sector,
    "freqs" : freqs
}

with open(indicators_dir.joinpath("Technology_2_3.pickle"), "wb") as fout:
    pickle.dump(data, fout)

# %%
# Save
jstruct.set_info(sector, freqs, ind="i09", sv="sector of organization")
jstruct.save()

# %% [markdown]
# ### 2.4. Technological production characteristics

# %% [markdown]
# #### 2.4.1. Patents by NACE code

# %%
# Enrich patents with NACE information

tls229 = spark.read.parquet(path2PATSTAT + "tls229.parquet")
PATSTAT_selected_NACE = PATSTAT_selected.join(tls229, on="appln_id", how="inner")

tls902 = spark.read.parquet(path2PATSTAT + "tls902.parquet").select(["nace2_code", "nace2_descr"]).dropDuplicates()
PATSTAT_selected_NACE = PATSTAT_selected_NACE.join(tls902, on="nace2_code", how="inner").cache()

print("Number of patents incorporating NACE information:", PATSTAT_selected_NACE.count())
PATSTAT_selected_NACE.printSchema()
PATSTAT_selected_NACE.show(n=2, truncate=120, vertical=True)
# Out:
# [Stage 103:=====================================================> (39 + 1) / 40]
# Number of patents incorporating NACE information: 13844
# root
#  |-- nace2_code: string (nullable = true)
#  |-- appln_id: string (nullable = true)
#  |-- docdb_family_id: string (nullable = true)
#  |-- appln_title: string (nullable = true)
#  |-- appln_title_lg: string (nullable = true)
#  |-- appln_abstract: string (nullable = true)
#  |-- appln_abstract_lg: string (nullable = true)
#  |-- appln_filing_year: string (nullable = true)
#  |-- earliest_filing_year: integer (nullable = true)
#  |-- granted: string (nullable = true)
#  |-- appln_auth: string (nullable = true)
#  |-- receiving_office: string (nullable = true)
#  |-- ipr_type: string (nullable = true)
#  |-- weight: string (nullable = true)
#  |-- nace2_descr: string (nullable = true)
#
# -RECORD 0----------------------------------------------------------------------------------------------------------------------------------------
#  nace2_code           | 21
#  appln_id             | 497480804
#  docdb_family_id      | 36090797
#  appln_title          | MONOCLONAL ANTIBODIES AGAINST CLAUDIN-18 FOR TREATMENT OF CANCER
#  appln_title_lg       | en
#  appln_abstract       | The present invention provides antibodies useful as therapeutics for treating and/or preventing diseases associated w...
#  appln_abstract_lg    | en
#  appln_filing_year    | 2006
#  earliest_filing_year | 2005
#  granted              | Y
#  appln_auth           | EP
#  receiving_office     |
#  ipr_type             | PI
#  weight               | 1.0
#  nace2_descr          | Manufacture of Basic Pharmaceutical Products and Pharmaceutical Preparations
# -RECORD 1----------------------------------------------------------------------------------------------------------------------------------------
#  nace2_code           | 21
#  appln_id             | 497480820
#  docdb_family_id      | 52274459
#  appln_title          | MUTATIONAL ANALYSIS OF PLASMA DNA FOR CANCER DETECTION
#  appln_title_lg       | en
#  appln_abstract       | A frequency of somatic mutations in a biological sample (e.g., plasma or serum) of a subject undergoing screening or ...
#  appln_abstract_lg    | en
#  appln_filing_year    | 2013
#  earliest_filing_year | 2012
#  granted              | Y
#  appln_auth           | EP
#  receiving_office     |
#  ipr_type             | PI
#  weight               | 1.0
#  nace2_descr          | Manufacture of Basic Pharmaceutical Products and Pharmaceutical Preparations
# only showing top 2 rows

# %%
PATSTAT_selected_NACE = PATSTAT_selected_NACE.withColumn("nace_out", F.concat_ws(" - ", PATSTAT_selected_NACE["nace2_code"], PATSTAT_selected_NACE["nace2_descr"]))
PATSTAT_selected_NACE = PATSTAT_selected_NACE.select(["nace_out", "weight"])

# %%
NACE_freq = PATSTAT_selected_NACE.groupBy("nace_out").agg(F.sum("weight").alias("total_weight")).rdd.collectAsMap()

# %%
NACE_freq
# Out:
# {'20.2 - Manufacture of Pesticides and Other Agrochemical Products': 24.575302410999996,
#  '26.2 - Manufacture of computers and peripheral equipment': 93.08334269599999,
#  '21 - Manufacture of Basic Pharmaceutical Products and Pharmaceutical Preparations': 7667.757337120001,
#  '32.5 - Manufacture of medical and dental instruments and supplies': 95.37427806599999,
#  '26.3 - Manufacture of Communication Equipment': 1.5252525,
#  '28.23 - Manufacture of Office Machinery and Equipment (Except Computers and Peripheral Equipment)': 14.134270782,
#  '27.2 - Manufacture of Batteries and Accumulators': 1.25,
#  '26.5 - Manufacture of Instruments and Appliances for Measuring, Testing and Navigation; Watches and Clocks': 1792.9069313869993,
#  '28.29 - Manufacture of Other General-Purpose Machinery N.E.C.': 3.2732804449999997,
#  '20.2 - Manufacture of pesticides and other agrochemical products': 24.575302410999996,
#  '26.6 - Manufacture of irradiation, electromedical and electrotherapeutic equipment': 19.314311654000004,
#  '20.1 - Manufacture of Basic Chemicals, Fertilisers and Nitrogen Compounds, Plastics and Synthetic Rubber in Primary Forms': 15.932691135999999,
#  '26.7 - Manufacture of Optical Instruments and Photographic Equipment': 1.792909398,
#  '26.11 - Manufacture of Electronic Components': 5.580644196,
#  '20.4 - Manufacture of Soap and Detergents, Cleaning and Polishing Preparations, Perfumes and Toilet Preparations': 3.49033271,
#  '26.1 - Manufacture of Electronic Components and Boards': 2.12116122,
#  '23.5 - Manufacture of Cement, Lime and Plaster': 0.16666667,
#  '10 - Manufacture of Food Products': 14.987411371,
#  '28.3 - Manufacture of Agricultural and Forestry Machinery': 24.84304746,
#  '20.42 - Manufacture of Perfumes and Toilet Preparations': 2.139257505,
#  '20.5 - Manufacture of Other Chemical Products': 18.383344502,
#  '62 - Computer Programming, Consultancy and Related Activities': 1.0095238199999998,
#  '28.99 - Manufacture of Other Special-Purpose Machinery N.E.C.': 1.697645855,
#  '28.9 - Manufacture of Other Special-Purpose Machinery': 1.48739497,
#  '24.46 - Processing of Nuclear Fuel': 0.125,
#  '14 - Manufacture of Wearing Apparel': 0.2,
#  '22 - Manufacture of Rubber and Plastic Products': 0.24313727000000002,
#  '11 - Manufacture of Beverages': 0.38809525,
#  '29.1 - Manufacture of Motor Vehicles': 1.741269856,
#  '26.4 - Manufacture of Consumer Electronics': 0.33333334,
#  '23 - Manufacture of Other Non-Metallic Mineral Products': 0.14285715,
#  '28.1 - Manufacture of General-Purpose Machinery': 0.16666667,
#  '23.1 - Manufacture of Glass and Glass Products': 0.11111111,
#  '28.4 - Manufacture of Metal Forming Machinery and Machine Tools': 0.75,
#  '27.9 - Manufacture of other electrical equipment': 0.66666668,
#  '27.9 - Manufacture of Other Electrical Equipment': 0.66666668,
#  '25.5 - Forging, Pressing, Stamping and Roll-Forming of Metal; Powder Metallurgy': 0.75,
#  '30 - Manufacture of Other Transport Equipment': 0.055555556,
#  '27.4 - Manufacture of Electric Lighting Equipment': 0.1,
#  '26.51 - Manufacture of Instruments and Appliances for Measuring, Testing and Navigation': 0.4}

# %%
# Sort results
NACE_freq  = sorted([(el[0].title(), el[1]) for el in NACE_freq.items()], key=lambda x: -x[1])[:100]

# %%
NACE, freqs = zip(*NACE_freq)

plt.figure(figsize=(8, 10))  
plt.barh(NACE, freqs)

plt.xlabel('Number of patents')
plt.ylabel('NACE')
plt.title('Number of patents per NACE')
plt.gca().invert_yaxis()  # Invert y axis

plt.show()

# %%
data = {
    "NACE" : NACE,
    "freqs" : freqs
}

with open(indicators_dir.joinpath("Technology_3_1.pickle"), "wb") as fout:
    pickle.dump(data, fout)

# %%
# Save
jstruct.set_info(NACE, freqs, ind="i09", sv="NACE of companies")
jstruct.save()

# %% [markdown]
# #### 2.4.2. Patents by IPC codes (top 20 codes)

# %%
# Enrich patents with IPC information

tls209 = spark.read.parquet(path2PATSTAT + "tls209.parquet").select(["appln_id", "ipc_class_symbol"])
PATSTAT_selected_IPC = PATSTAT_selected.join(tls209, on="appln_id", how="inner")
PATSTAT_selected_IPC = PATSTAT_selected_IPC.withColumn("IPC", F.substring(F.col("ipc_class_symbol"), 1, 3))
PATSTAT_selected_IPC = PATSTAT_selected_IPC.select(["appln_id", "IPC"]).dropDuplicates()

# %%
IPC_freq = PATSTAT_selected_IPC.groupBy("IPC").agg(F.count("*").alias("counts")).rdd.collectAsMap()

# %%
IPC_descriptions = {
    'A01': 'Agriculture; Forestry; Animal Husbandry; Hunting; Trapping; Fishing',
    'A21': 'Baking; Edible Doughs',
    'A23': 'Foods or Foodstuffs; Treatment Thereof, Not Covered by Other Classes',
    'A41': 'Wearing Apparel',
    'A61': 'Medical or Veterinary Science; Hygiene',
    'B01': 'Physical or Chemical Processes or Apparatus in General',
    'B03': 'Separation of Solid Materials Using Liquids or Using Pneumatic Tables or Jigs; Magnetic or Electrostatic Separation of Solid Materials from Solid Materials or Fluids; Separation by High-Voltage Electric Fields',
    'B05': 'Spraying or Atomising in General; Applying Fluids',
    'B07': 'Separating Solids from Solids; Sorting',
    'B22': 'Casting; Powder Metallurgy',
    'B25': 'Hand Tools; Portable Power-Driven Tools; Handles for Hand Implements; Workshop Equipment; Manipulators',
    'B27': 'Working or Preserving Wood or Similar Material; Nailing or Stapling Machines in General',
    'B29': 'Working of Plastics; Working of Substances in a Plastic State in General',
    'B32': 'Layered Products',
    'B60': 'Vehicles in General',
    'B62': 'Land Vehicles for Travelling Otherwise Than on Rails',
    'B64': 'Aircraft; Aviation; Cosmonautics',
    'B67': 'Opening or Closing Bottles, Jars or Similar Containers; Liquid Handling',
    'B81': 'Microstructural Technology',
    'C01': 'Inorganic Chemistry',
    'C02': 'Treatment of Water, Waste Water, Sewage, or Sludge',
    'C03': 'Glass; Mineral or Slag Wool',
    'C04': 'Cement, Concrete, Artificial Stone, Ceramics, Refractories',
    'C07': 'Organic Chemistry',
    'C08': 'Organic Macromolecular Compounds; Their Preparation or Chemical Working-Up; Compositions Based Thereon',
    'C09': 'Dyes; Paints; Polishes; Natural Resins; Adhesives; Compositions Not Otherwise Provided for; Applications of Materials Not Otherwise Provided for',
    'C10': 'Petroleum, Gas or Coke Industries; Technical Gases Containing Carbon Monoxide; Fuels; Lubricants; Peat',
    'C11': 'Animal or Vegetable Fats, Oils, Fatty Substances, or Waxes; Fatty Acids Therefrom; Detergents; Candles',
    'C12': 'Biochemistry; Beer; Spirits; Wine; Vinegar; Microbiology; Enzymology; Mutation or Genetic Engineering',
    'C23': 'Coating Metallic Material; Coating Material with Metallic Material; Chemical Surface Treatment; Diffusion Treatment of Metallic Material; Coating by Vacuum Evaporation, by Sputtering, by Ion Implantation or by Chemical Vapour Deposition, in General',
    'F02': 'Combustion Engines; Hot-Gas or Combustion-Product Engine Plants',
    'F04': 'Positive Displacement Machines for Liquids; Pumps for Liquids or Elastic Fluids',
    'F21': 'Lighting',
    'F26': 'Drying',
    'G01': 'Measuring; Testing',
    'G02': 'Optics',
    'G05': 'Controlling; Regulating',
    'G06': 'Computing; Calculating; Counting',
    'G07': 'Checking Devices',
    'G10': 'Musical Instruments; Acoustics',
    'G11': 'Information Storage',
    'G16': 'Information and Communication Technology [ICT] Specially Adapted for Specific Application Fields',
    'G21': 'Nuclear Physics; Nuclear Engineering',
    'H01': 'Basic Electric Elements',
    'H03': 'Basic Electronic Circuitry',
    'H04': 'Electric Communication Technique',
    'H05': 'Electric Techniques Not Otherwise Provided for'
}

IPC_descriptions = {el[0] : el[1].title() for el in IPC_descriptions.items()}

# %%
IPC_freq_desc = {}

for el in IPC_freq:
    if el in IPC_descriptions:
        IPC_freq_desc[IPC_descriptions[el]] = IPC_freq[el]
    else:
        IPC_freq_desc[el] = IPC_freq[el]

# %%
# Sort results
IPC_freq_desc  = sorted([(el[0].title(), el[1]) for el in IPC_freq_desc.items()], key=lambda x: -x[1])

# %%
IPC, freqs = zip(*IPC_freq_desc)

plt.figure(figsize=(8, 10))  
plt.barh(IPC, freqs)

plt.xlabel('Number of patents')
plt.ylabel('NACE')
plt.title('Number of patents per IPC')
plt.gca().invert_yaxis()  # Invert y axis

plt.show()

# %%
data = {
    "IPC" : IPC,
    "freqs" : freqs
}

with open(indicators_dir.joinpath("Technology_3_2.pickle"), "wb") as fout:
    pickle.dump(data, fout)

# %%
# Save
jstruct.set_info(IPC, freqs, ind="i09", sv="IPC/CPC code")
jstruct.save()

# %% [markdown]
# #### 2.4.3. Patents by topic

# %%
patents_id = PATSTAT_selected.select("appln_id").rdd.flatMap(lambda x: x).collect()
patents_id = set(patents_id)
pos = [idx for idx,val in enumerate(corpus_LDA) if val in patents_id]
patents_per_topic = np.sum(thetas_LDA[pos,:], axis=0).tolist()[0]

# %%
plt.figure(figsize=(8, 10))
plt.barh(topics_LDA, patents_per_topic)

plt.xlabel('Number of publications')
plt.ylabel('Topic')
plt.title('International collaborations by topic')
plt.gca().invert_yaxis()  # Invert axis

plt.show()

# %%
data = {
    "topics_LDA": topics_LDA,
    "patents_per_topic" : patents_per_topic
}

with open(indicators_dir.joinpath("Technology_3_3.pickle"), "wb") as fout:
    pickle.dump(data, fout)

# %%
# Save
jstruct.set_info(topics_LDA, patents_per_topic, ind="i09", sv="topic")
jstruct.save()
