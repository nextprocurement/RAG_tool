# %%
import pandas
import pandas as pd
import fasttext
from huggingface_hub import hf_hub_download
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
# Define the figure size and dpi
fig_width = 6.9  # inches
fig_height = 3.5  # inches
fig_dpi = 350

plt.rcParams.update({
    'figure.figsize': (fig_width, fig_height),
    'figure.dpi': fig_dpi,

    # Fonts
    'font.size': 24,

    # Axes
    'axes.labelsize': 24,
    'axes.titlesize': 24,
    'axes.linewidth': 1,
    'axes.grid': True,
    'grid.linestyle': ':',
    'grid.linewidth': 1,
    'grid.color': 'gray',

    # Legend
    'legend.fontsize': 24,
    'legend.frameon': True,
    'legend.framealpha': 0.8,
    'legend.fancybox': False,
    'legend.edgecolor': 'gray',
    'legend.facecolor': 'white',
    'legend.borderaxespad': 0.5,
    'legend.borderpad': 0.4,
    'legend.labelspacing': 0.5,

    # Lines
    'lines.linewidth': 2.0,
    'lines.markersize': 2,
    'axes.labelsize': 24,
    'axes.titlesize': 24,
    'xtick.labelsize': 18,
    'ytick.labelsize': 18,
})

# %%
labels = ['PLACE', 'S2CS-AI']
label_1 = [46, 10]
label_2 = [30, 87]
label_3 = [45, 108]
label_4 = [19, 95]

label_1_normalized = [label_1[0] / 140, label_1[1] / 300]
label_2_normalized = [label_2[0] / 140, label_2[1] / 300]
label_3_normalized = [label_3[0] / 140, label_3[1] / 300]
label_4_normalized = [label_4[0] / 140, label_4[1] / 300]

bar_width = 0.2

r1 = np.arange(len(labels))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]

# Create the plot
#plt.figure(figsize=(8, 6))
plt.bar(r1, label_1_normalized, color='#55a2a8', width=bar_width, label='1')
plt.bar(r2, label_2_normalized, color='#234567', width=bar_width, label='2')
plt.bar(r3, label_3_normalized, color='#a3e5a1', width=bar_width, label='3')
plt.bar(r4, label_4_normalized, color='#345678', width=bar_width, label='4')

#plt.xlabel('Dataset')
plt.ylabel('Ratings')
plt.xticks([r + bar_width for r in range(len(labels))], labels)
# Place the legend above the plot, ensuring it's not cut off
plt.legend(ncol=4, fontsize="small", loc='upper center', bbox_to_anchor=(0.5, 1.22), 
           labelspacing=0, borderpad=0.1, frameon=True)

# Save the plot with 'bbox_inches' set to 'tight' to avoid cutting off content
plt.savefig("annotations_v2.png", bbox_inches='tight')
plt.show()
